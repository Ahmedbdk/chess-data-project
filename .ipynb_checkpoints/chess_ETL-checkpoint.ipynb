# %%
import pandas as pd
import numpy as np
import requests

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; ChessDataBot/1.0)"
}

def get_archives(username):
    url = f"https://api.chess.com/pub/player/{username}/games/archives"
    response = requests.get(url, headers=HEADERS)

    if response.status_code != 200:
        raise Exception(f"Erreur API archives: {response.status_code}")

    return response.json()["archives"]

# %%
def get_player_country(username):
    url = f"https://api.chess.com/pub/player/{username}"
    response = requests.get(url, headers=HEADERS)

    if response.status_code != 200:
        raise Exception(f"Erreur API games: {response.status_code}")

    country_url = response.json()["country"]

    response = requests.get(country_url, headers=HEADERS)

    if response.status_code != 200:
        raise Exception(f"Erreur API games: {response.status_code}")

    return response.json()["name"]

# %%
get_player_country("dengrimmeko")
# Out:
# 'Tunisia'

# %%
def get_games_from_archive(archive_url):
    response = requests.get(archive_url, headers=HEADERS)

    if response.status_code != 200:
        raise Exception(f"Erreur API games: {response.status_code}")

    return response.json()["games"]

# %%
def parse_games(games):
    table = []

    for game in games:
        row = {
            "uuid": game.get("uuid"),
            "url": game.get("url"),
            "white": game["white"]["username"],
            "black": game["black"]["username"],
            "result_white": game["white"]["result"],
            "result_black": game["black"]["result"],
            "white_elo": game["white"]["rating"],
            "black_elo": game["black"]["rating"],
            "time_control": game.get("time_control"),
            "time_class": game.get("time_class"),
            "rated": game.get("rated"),
            "eco": game.get("eco"),
            "accuracy_white": game.get("accuracies", {}).get("white"),
            "accuracy_black": game.get("accuracies", {}).get("black"),
            "pgn": game.get("pgn"),
            "end_time": game.get("end_time")
        }

        table.append(row)

    return table

# %%
username = "ahmedbdk"
username =username.lower()
# 1. récupérer les archives
archives = get_archives(username)

games = []

# 2. Parcourir toutes les archives
for archive in archives:
    # 3. récupérer les parties
    games += get_games_from_archive(archive)
    

# 4. parser les parties dans un tableau
table = parse_games(games)

# 5. résultat
print(f"{len(table)} parties récupérées")
# Out:
# 3168 parties récupérées

# %%
bronze_df = pd.DataFrame(table)

# %%
bronze_df.head(2)
# Out:
#                                    uuid  \
# 0  eb87036c-c29a-11ee-aec6-6cfe544c0428
# 1  1ed33952-c29c-11ee-aec6-6cfe544c0428
#
#                                             url         white         black  \
# 0  https://www.chess.com/game/live/100707178017  HousseMiladi      Ahmedbdk
# 1  https://www.chess.com/game/live/100707748759      Ahmedbdk  HousseMiladi
#
#   result_white result_black  white_elo  black_elo time_control time_class  \
# 0          win   checkmated        513        400          600      rapid
# 1   checkmated          win        400        513          600      rapid
#
#    rated                                                eco  accuracy_white  \
# 0  False         https://www.chess.com/openings/Scotch-Game             NaN
# 1  False  https://www.chess.com/openings/Kings-Pawn-Open...             NaN
#
#    accuracy_black                                                pgn  \
# 0             NaN  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...
# 1             NaN  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...
#
#      end_time
# 0  1706968609
# 1  1706969347

# %%
silver_df = bronze_df.copy()

# %%
silver_df['white'] = silver_df['white'].str.lower()
silver_df['black'] = silver_df['black'].str.lower()
silver_df[['accuracy_white','accuracy_black']] = silver_df[['accuracy_white','accuracy_black']].fillna('None')
silver_df['end_datetime'] = pd.to_datetime(bronze_df['end_time'], unit='s')
silver_df['rated'] = silver_df['rated'].astype(bool)
silver_df[['white_elo','black_elo']] = silver_df[['white_elo','black_elo']].astype(int)
silver_df = silver_df.drop_duplicates(subset='uuid')

# %%
silver_df.head(2)
# Out:
#                                    uuid  \
# 0  eb87036c-c29a-11ee-aec6-6cfe544c0428
# 1  1ed33952-c29c-11ee-aec6-6cfe544c0428
#
#                                             url         white         black  \
# 0  https://www.chess.com/game/live/100707178017  houssemiladi      ahmedbdk
# 1  https://www.chess.com/game/live/100707748759      ahmedbdk  houssemiladi
#
#   result_white result_black  white_elo  black_elo time_control time_class  \
# 0          win   checkmated        513        400          600      rapid
# 1   checkmated          win        400        513          600      rapid
#
#    rated                                                eco accuracy_white  \
# 0  False         https://www.chess.com/openings/Scotch-Game           None
# 1  False  https://www.chess.com/openings/Kings-Pawn-Open...           None
#
#   accuracy_black                                                pgn  \
# 0           None  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...
# 1           None  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...
#
#      end_time        end_datetime
# 0  1706968609 2024-02-03 13:56:49
# 1  1706969347 2024-02-03 14:09:07

# %%
gold_df = silver_df.copy()

# %%
gold_df['player'] = username
gold_df['opponent'] = np.where (
    (username == gold_df ['white']),
     gold_df['black'],
     gold_df['white'])
gold_df['result'] = np.where (
    (username == gold_df['white']),
    gold_df['result_white'],
    gold_df['result_black'])
gold_df['player_elo'] = np.where (
    (username == gold_df ['white']),
    gold_df['white_elo'],
    gold_df['black_elo'])
gold_df['opponent_elo'] = np.where (
    (username == gold_df ['white']),
    gold_df['black_elo'],
    gold_df['white_elo'])
gold_df['player_color'] = np.where (
    (username == gold_df['white']),
    'white',
    'black')
gold_df['opponent_color'] = np.where (
    (username == gold_df['white']),
    'black',
    'white')
gold_df['player_accuracy'] = np.where (
    (username == gold_df['white']),
    gold_df['accuracy_white'],
    gold_df['accuracy_black'])
gold_df['opponent_accuracy'] = np.where (
    (username == gold_df['white']),
    gold_df['accuracy_black'],
    gold_df['accuracy_white'])

gold_df['opening'] = gold_df['eco'].str.split('openings/').str[1]

# %%
new_order = ['uuid','player','player_elo','opponent','opponent_elo','player_color','opponent_color','result','time_class','time_control','opening','rated','end_datetime','player_accuracy','opponent_accuracy','url']
gold_df = gold_df[new_order]

# %%
gold_df.head(10)
# Out:
#                                    uuid    player  player_elo  \
# 0  eb87036c-c29a-11ee-aec6-6cfe544c0428  ahmedbdk         400
# 1  1ed33952-c29c-11ee-aec6-6cfe544c0428  ahmedbdk         400
# 2  5c9a35d4-c364-11ee-aec6-6cfe544c0428  ahmedbdk         400
# 3  4e1f4881-c3af-11ee-aec6-6cfe544c0428  ahmedbdk         400
# 4  d0b12f0e-c3af-11ee-aec6-6cfe544c0428  ahmedbdk         400
# 5  d62d3076-c444-11ee-8606-1622bd01000f  ahmedbdk         231
# 6  8d68ab33-c595-11ee-aec6-6cfe544c0428  ahmedbdk         164
# 7  093a0713-c599-11ee-8c6c-65ec0601000f  ahmedbdk         262
# 8  d092224f-c599-11ee-aec6-6cfe544c0428  ahmedbdk         296
# 9  79f1cbab-c5a1-11ee-aec6-6cfe544c0428  ahmedbdk         251
#
#           opponent  opponent_elo player_color opponent_color      result  \
# 0     houssemiladi           513        black          white  checkmated
# 1     houssemiladi           513        white          black  checkmated
# 2     houssemiladi           536        black          white  checkmated
# 3     houssemiladi           525        black          white         win
# 4     houssemiladi           525        white          black  checkmated
# 5        danyagggy           420        white          black    resigned
# 6     dalleji4real           514        white          black   abandoned
# 7  stilllearning81           134        white          black         win
# 8     dalleji4real           433        white          black      agreed
# 9     dalleji4real           508        black          white    resigned
#
#   time_class time_control                                            opening  \
# 0      rapid          600                                        Scotch-Game
# 1      rapid          600  Kings-Pawn-Opening-Leonardis-Variation-2...Nf6...
# 2      rapid          600                            Ponziani-Opening-3...d6
# 3      rapid          600                                    Petrovs-Defense
# 4      rapid          600                                    Petrovs-Defense
# 5      rapid          600                                  Alekhines-Defense
# 6      rapid          600          Kings-Pawn-Opening-Kings-Knight-Variation
# 7      rapid          600               Kings-Pawn-Opening-St-George-Defense
# 8      rapid          600                                       Pirc-Defense
# 9      rapid          600                          Kings-Pawn-Opening-1...e5
#
#    rated        end_datetime player_accuracy opponent_accuracy  \
# 0  False 2024-02-03 13:56:49            None              None
# 1  False 2024-02-03 14:09:07            None              None
# 2  False 2024-02-04 14:06:14           51.07             61.06
# 3  False 2024-02-04 22:50:34           45.59             65.78
# 4  False 2024-02-04 22:59:27           52.65             73.22
# 5   True 2024-02-05 16:53:06            None              None
# 6   True 2024-02-07 09:05:59           36.61             33.81
# 7   True 2024-02-07 09:16:43            None              None
# 8   True 2024-02-07 10:12:50            None              None
# 9   True 2024-02-07 10:15:37            None              None
#
#                                             url
# 0  https://www.chess.com/game/live/100707178017
# 1  https://www.chess.com/game/live/100707748759
# 2  https://www.chess.com/game/live/100793622925
# 3  https://www.chess.com/game/live/100825937775
# 4  https://www.chess.com/game/live/100825997917
# 5  https://www.chess.com/game/live/100765867878
# 6  https://www.chess.com/game/live/101034744585
# 7  https://www.chess.com/game/live/100992061694
# 8  https://www.chess.com/game/live/101036554195
# 9  https://www.chess.com/game/live/101039637023

# %%
output_path = f"chess_games_{username}_gold.csv"

gold_df.to_csv(
    output_path,
    index=False,
    encoding="utf-8"
)

# %%
archives[-1]
# Out:
# 'https://api.chess.com/pub/player/ahmedbdk/games/2025/09'
