# %%
import pandas as pd
import numpy as np
import requests
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; ChessDataBot/1.0)"
}

def get_archives(username):
    url = f"https://api.chess.com/pub/player/{username}/games/archives"
    response = requests.get(url, headers=HEADERS)

    if response.status_code != 200:
        raise Exception(f"Erreur API archives: {response.status_code}")

    return response.json()["archives"]

# %%
def get_player_country(username):
    if not username:
        return None

    try:
        url = f"https://api.chess.com/pub/player/{username}"
        r = requests.get(url, headers=HEADERS, timeout=10)

        if r.status_code != 200:
            return None

        data = r.json()
        country_url = data.get("country")

        if not country_url:
            return None

        return country_url.split("/")[-1]

    except Exception:
        return None

# %%
def get_games_from_archive(archive_url):
    response = requests.get(archive_url, headers=HEADERS)

    if response.status_code != 200:
        raise Exception(f"Erreur API games: {response.status_code}")

    return response.json()["games"]

# %%
def parse_games(games):
    table = []

    for game in games:
        row = {
            "uuid": game.get("uuid"),
            "url": game.get("url"),
            "white": game["white"]["username"],
            "black": game["black"]["username"],
            "result_white": game["white"]["result"],
            "result_black": game["black"]["result"],
            "white_elo": game["white"]["rating"],
            "black_elo": game["black"]["rating"],
            "time_control": game.get("time_control"),
            "time_class": game.get("time_class"),
            "rated": game.get("rated"),
            "eco": game.get("eco"),
            "accuracy_white": game.get("accuracies", {}).get("white"),
            "accuracy_black": game.get("accuracies", {}).get("black"),
            "pgn": game.get("pgn"),
            "end_time": game.get("end_time")
        }

        table.append(row)

    return table

# %%
username = "ahmedbdk"
username =username.lower()
# 1. récupérer les archives
archives = get_archives(username)

games = []

# 2. Parcourir toutes les archives
for archive in archives:
    # 3. récupérer les parties
    games += get_games_from_archive(archive)
    

# 4. parser les parties dans un tableau
table = parse_games(games)

# 5. résultat
print(f"{len(table)} parties récupérées")
# Out:
# 3168 parties récupérées

# %%
bronze_df = pd.DataFrame(table)

# %%
silver_df = bronze_df.copy()

# %%
silver_df['white'] = silver_df['white'].str.lower()
silver_df['black'] = silver_df['black'].str.lower()
silver_df[['accuracy_white','accuracy_black']] = silver_df[['accuracy_white','accuracy_black']].fillna('None')
silver_df['end_datetime'] = pd.to_datetime(bronze_df['end_time'], unit='s')
silver_df['rated'] = silver_df['rated'].astype(bool)
silver_df[['white_elo','black_elo']] = silver_df[['white_elo','black_elo']].astype(int)
silver_df = silver_df.drop_duplicates(subset='uuid')

# %%
gold_df = silver_df.copy()

# %%
gold_df['player'] = username
gold_df['opponent'] = np.where (
    (username == gold_df ['white']),
     gold_df['black'],
     gold_df['white'])
gold_df['result'] = np.where (
    (username == gold_df['white']),
    gold_df['result_white'],
    gold_df['result_black'])
gold_df['player_elo'] = np.where (
    (username == gold_df ['white']),
    gold_df['white_elo'],
    gold_df['black_elo'])
gold_df['opponent_elo'] = np.where (
    (username == gold_df ['white']),
    gold_df['black_elo'],
    gold_df['white_elo'])
gold_df['player_color'] = np.where (
    (username == gold_df['white']),
    'white',
    'black')
gold_df['opponent_color'] = np.where (
    (username == gold_df['white']),
    'black',
    'white')
gold_df['player_accuracy'] = np.where (
    (username == gold_df['white']),
    gold_df['accuracy_white'],
    gold_df['accuracy_black'])
gold_df['opponent_accuracy'] = np.where (
    (username == gold_df['white']),
    gold_df['accuracy_black'],
    gold_df['accuracy_white'])

gold_df['opening'] = gold_df['eco'].str.split('openings/').str[1]

# %%
new_order = ['uuid','player','player_elo','opponent','opponent_elo','player_color','opponent_color','result','time_class','time_control','opening','rated','end_datetime','player_accuracy','opponent_accuracy','url']
gold_df = gold_df[new_order]

# %%
unique_opponents = gold_df['opponent'].dropna().unique()
len(unique_opponents)
# Out:
# 3023

# %%
opponent_country_map = {}

with ThreadPoolExecutor(max_workers=15) as executor:
    results = executor.map(get_player_country, unique_opponents)

    for opponent, country in tqdm(
        zip(unique_opponents, results),
        total=len(unique_opponents),
        desc="Fetching opponent countries"
    ):
        opponent_country_map[opponent] = country
# Out:
# Fetching opponent countries: 100%|█████████████████████████████████████████████████| 3023/3023 [36:31<00:00,  1.38it/s]

# %%
opponent_country_map
# Out:
# {'houssemiladi': 'Tunisia',
#  'danyagggy': 'Kazakhstan',
#  'dalleji4real': 'France',
#  'stilllearning81': 'United States',
#  'azzipi': 'Thailand',
#  'piyushbhatia2': 'India',
#  'mneimar1': 'Morocco',
#  'valle546': 'Germany',
#  'bolagato3': 'Brazil',
#  'fco_lazcano-inactive': 'Chile',
#  'zimians': 'South Africa',
#  'selvadarshu': 'Malaysia',
#  'vyom1401': 'Sweden',
#  'jugobetrugo1223': 'Germany',
#  'peterbennett04': 'United Kingdom',
#  'tiwana1777': 'Canada',
#  '5439hfkfo': 'China',
#  'chess12345612345': 'United Kingdom',
#  'toomag': 'Iran',
#  'ravenous_demon1134': 'United States',
#  'shorouk02': 'Italy',
#  'lyphu': 'Vietnam',
#  'chessearner555': 'India',
#  'riderp82': 'India',
#  'kchessboard': 'Algeria',
#  'eavvbb': 'Italy',
#  'shonathebest': 'Canada',
#  'miagame': 'North Korea',
#  'mayar9998': 'Saudi Arabia',
#  'mmaalik01': 'Canada',
#  'gagimirka': 'Serbia',
#  'patrikfelix': 'Slovakia',
#  'dr7yaya': 'India',
#  'zurye': 'Mexico',
#  'mrhamidrezaa': 'Iran',
#  'fisu1330': 'Uruguay',
#  'geedi23': 'Sweden',
#  'tatan9402': 'Colombia',
#  'hiradanish': 'United States',
#  'phoenixak47': 'Bangladesh',
#  'iwilldefeatadi': 'India',
#  'ice_tain': 'South Korea',
#  'f1kj5n1': 'Singapore',
#  'virunbhai94': 'India',
#  'nerthee': 'United Kingdom',
#  'perejoan03': 'Spain',
#  'crowomagnifico': 'Brazil',
#  'sierrasierra1': 'India',
#  'johnny123chess': 'Ethiopia',
#  'anaskufche': None,
#  'khagger': 'United States',
#  'ralphrizzy': 'United States',
#  'gbrshthrpwd': 'France',
#  't3mmm': 'Philippines',
#  'hubertkusal': 'Poland',
#  'peter14264': 'India',
#  'racecar_0013': 'United States',
#  'princessenora': 'France',
#  'mozzo223': 'Italy',
#  'a_karlaaaaal': 'Pakistan',
#  'julesrhys': 'Australia',
#  'l00rdinho': 'Brazil',
#  'nirro26': 'France',
#  'tomasharcar': 'United Kingdom',
#  'brabusg8': 'Ukraine',
#  'thao2412': 'Vietnam',
#  'kamilkazgrilka': 'Poland',
#  'kenngaongo2509': 'Vietnam',
#  'yossefmagdy682012': 'Egypt',
#  'joanne1300': 'United States',
#  'svnaik': 'India',
#  'nottoday006666': 'India',
#  'jeanyin': 'Spain',
#  'javi_18ct': 'Spain',
#  'salih_8': 'Türkiye',
#  'djeb987': 'France',
#  'xxhensxx': 'Wales',
#  'itstinkerbelle': 'Philippines',
#  'astrothechessking': 'United States',
#  'woo5192': 'United States',
#  'zacc1997': 'United States',
#  'charu_1991': 'India',
#  'deadlygamerog': 'India',
#  'vicenby': 'Spain',
#  'david_leanca': 'Moldova',
#  'ahmed_goger': 'Romania',
#  'rizwanahmed12': 'Pakistan',
#  'jamo023': 'United Kingdom',
#  'luffykingofthpirate': 'India',
#  'totsuka19': 'Brazil',
#  'puv71': 'Spain',
#  'duasweety': 'United Arab Emirates',
#  'shashi_yadav21': 'India',
#  'rlklibra': 'France',
#  'johan073081': 'Luxembourg',
#  'leonp98': 'United Kingdom',
#  'ceddie11': 'Germany',
#  'olisnaer': 'Iceland',
#  'cesticles': 'Ireland',
#  'sporehorizont': 'Austria',
#  'y7t': 'United States',
#  'itz_me_abid': 'Bangladesh',
#  'zeynep3441': 'Türkiye',
#  'aeduardozrx': 'Brazil',
#  'eureka7astral': 'United States',
#  'voldemort1196': 'Germany',
#  'jitesh107': 'India',
#  'minzdu05': 'France',
#  'mazimn': 'Malaysia',
#  '7ussein_e-aljamal': 'Canada',
#  'sarahbail03': 'International',
#  'shusher122shush': 'Sweden',
#  'kimngan01112009': 'Vietnam',
#  'icy2blizz': 'United States',
#  'elfrine': 'United States',
#  'shiiiiii_22': 'India',
#  'redqkc19': 'United Kingdom',
#  'jelias74': 'Colombia',
#  'faiqzainal': 'Malaysia',
#  'omarr10x': 'Bosnia-Herzegovina',
#  'ejmejmejmejm': 'United States',
#  'luccas220': 'Brazil',
#  'fiestapotatoes': 'United States',
#  'dstrydavid': 'Germany',
#  'dbapfa': 'Spain',
#  'mushucc': 'Chile',
#  'justbe123123': 'United Kingdom',
#  'isa_lemuar': 'Italy',
#  'shazeeb123': 'Norway',
#  'julien3212': 'France',
#  'elcioneoliveira': 'Brazil',
#  '75re': 'Italy',
#  'kevineckstein': 'Trinidad/Tobago',
#  'garyp55': 'United States',
#  'iycrtgtfo': 'United States',
#  'emreckmk20': 'Türkiye',
#  'nachiket_kamdar2008': 'India',
#  'celinafr': 'Austria',
#  'plsletmeplayplspls': 'Italy',
#  'indrakarki123': 'Nepal',
#  'jbsoloman5000': 'South Africa',
#  'ikoav': 'Italy',
#  'charlysgambit': 'Austria',
#  'severochek': 'Ukraine',
#  'dertlok': 'United States',
#  '8_camilo_2': 'Mexico',
#  'amaury67000': 'France',
#  'netsi11': 'Ethiopia',
#  'daningalvao': 'Brazil',
#  'satyam4392': 'India',
#  'jmmartinavila': 'Spain',
#  'schauhan7': 'India',
#  'denofr': 'Türkiye',
#  'sshhh2004': 'Saudi Arabia',
#  'naserpouyan': 'Iran',
#  'charcuterieee': 'Australia',
#  'elephant40000': 'Canada',
#  'chessgodkerr': 'United States',
#  'owentheawesome4422': 'United States',
#  'blackgod717': 'United States',
#  'thekingisbackkkkk': 'North Korea',
#  'hundal94': 'Canada',
#  'itsjr20': 'United States',
#  'mayssenid': 'Tunisia',
#  'vladdraculaaa': 'India',
#  'titanic_pawntiff': 'United States',
#  'ply1974': 'Netherlands',
#  'chaulin_is_chaulin': 'Brazil',
#  'wagioo': 'Egypt',
#  'goosterblack': 'France',
#  'ranvijay-1993': 'India',
#  'melaso56': 'United States',
#  'rynerich': 'United States',
#  'hsnyr': 'Pakistan',
#  'frvk123': 'India',
#  'kieutrang3454': 'Vietnam',
#  'dybelton': 'United States',
#  '1011lpql': 'Ecuador',
#  'happybob21': 'United Kingdom',
#  'mo0rra': 'United States',
#  'dady11': 'Romania',
#  'eltoney': 'Egypt',
#  'saraj26': 'Iraq',
#  'umisnzjzzn': 'India',
#  'manolitoqk': 'Spain',
#  'sanspixel': 'United States',
#  'paurupablo': 'Canada',
#  'squallexino': 'Ukraine',
#  'blacktearr': 'Poland',
#  'ashokv9': 'India',
#  'mirzle': 'Australia',
#  'psahmed128555': 'Tunisia',
#  'winmarta': 'United Kingdom',
#  'soiney2023': 'Brazil',
#  'dankdavetharave': 'United Kingdom',
#  'ju_ng67': 'Finland',
#  'nscag': 'Australia',
#  'bahaehh': 'Morocco',
#  'sakshigadgil': 'India',
#  'sullyc101': 'Netherlands',
#  'victormasacree': 'Venezuela',
#  'math_y0u': 'United States',
#  'mrgrange': 'United States',
#  'autcarlsen': 'Austria',
#  'thekidlaroi_27': 'United States',
#  'malowski1985': 'Isle of Man',
#  'uhhdalg': 'Philippines',
#  'x-8833833077': 'International',
#  'misters128': 'Slovakia',
#  'ashish7874': 'India',
#  'archanavellore': 'India',
#  'champion007xd': 'India',
#  'noobwarrior69': 'Nigeria',
#  'khaleel000': 'Argentina',
#  'smon1981': 'United Kingdom',
#  'woosungwarrior': 'United States',
#  'el3nkeer': 'Egypt',
#  'edbrooook': 'Portugal',
#  'suresh-90': 'India',
#  'amanop567': 'India',
#  'doctorshiv13': 'India',
#  'tone4321': 'United States',
#  'aarab_bhai_on_top': 'India',
#  'prernachandani': 'India',
#  'ani6780': 'India',
#  'farawayfromyoua': 'United States',
#  'lukastmd': 'Poland',
#  'bulatov24': 'Russia',
#  'bala020201': 'India',
#  'ranjana1972': 'India',
#  'romanfrolov': 'Russia',
#  'anatoliy7105': 'Russia',
#  'vincent7891': 'India',
#  'yusufgzkck': 'Türkiye',
#  'kmong012': 'India',
#  'amr_hassan12347': 'Israel',
#  'silviacre': 'Ecuador',
#  'jb_313': 'United States',
#  '9999lv': 'South Korea',
#  'el_pollon01': 'El Salvador',
#  'youngdjango98': 'United Kingdom',
#  'mohitsolo_x': 'India',
#  'babonibf': 'India',
#  'din_loyd': 'India',
#  'sweart18': 'Portugal',
#  'abdullahf15v': 'Saudi Arabia',
#  'ostronow666': 'Germany',
#  'fathiru': 'Indonesia',
#  'juanillo81': 'Spain',
#  'kimyoungjo222': 'South Korea',
#  'parmod2023': 'India',
#  'vanderstorg': 'France',
#  'gefkouk': 'France',
#  'thewhiteberman': 'Morocco',
#  'rachit_2105': 'India',
#  'yash4dubariya': 'India',
#  'yourlovemelody': 'United Arab Emirates',
#  'ashaleag': 'India',
#  'iqsssss': 'India',
#  'djdhdhshshshshdhdhrhrhrhr': 'India',
#  'swifzzx': 'Brazil',
#  'mustidoc777': 'India',
#  'dutrinha0': 'Brazil',
#  'kashishkim': 'Canada',
#  'athuz91': 'India',
#  'buyanaakhuu': 'Mongolia',
#  'akkubhai26': 'India',
#  'komiljon1307': 'Uzbekistan',
#  'ambberlab': 'International',
#  'meguf': 'United States',
#  'nikib42': 'United Kingdom',
#  'sebastian1498': 'Colombia',
#  'lathekeon': 'Thailand',
#  'omar535o': 'Egypt',
#  'siri-jdma': 'Mexico',
#  'capolupi': 'Italy',
#  'lakhan9999': 'India',
#  'martsoni': 'Spain',
#  'smv3': 'Finland',
#  'hdhajbdvd': 'India',
#  'dudapirangx': 'Indonesia',
#  'pipipicasso': 'Singapore',
#  'devthakuri': 'Nepal',
#  'mkjha1': 'India',
#  'fiejdi': 'Poland',
#  '0o0whatings': 'India',
#  'plip612': 'South Korea',
#  'nithish772007': 'India',
#  'garrettisok': 'United States',
#  'louisr27': 'United Kingdom',
#  'drzed3': 'International',
#  'rocuma': 'Mexico',
#  'zaid707': 'Morocco',
#  'ghostblue93': 'France',
#  'osamaalking': 'Egypt',
#  'dil_283': 'India',
#  'globule_bcn': 'Spain',
#  'sankarsahoo': 'India',
#  'atauriko': 'Basque Country',
#  'kooky53': 'India',
#  'sinahadadi': 'Iran',
#  'histoevil': 'International',
#  'aroojkiran': 'Pakistan',
#  'lakeyj44': 'United States',
#  'supreethanaveen': 'India',
#  'ibrahimelagamy74': 'Egypt',
#  'sholett': 'Russia',
#  'geraldina1224': 'Albania',
#  'bigmoth00': 'Brazil',
#  'yeonseong12345gmailcom': 'South Korea',
#  'jetlosjjw': 'Philippines',
#  'notfall07': 'United States',
#  'dftjg': 'Ukraine',
#  'pansoul': 'Greece',
#  'kavyeshg': 'India',
#  'iosouy': 'Argentina',
#  'steliostsip': 'Greece',
#  'moh0699': 'Iran',
#  'gge4567': 'Ukraine',
#  'mrschwaggins': 'Germany',
#  'probablyadamm': 'Egypt',
#  'kalaisaran_24': 'Sri Lanka',
#  'lvkas561': 'International',
#  'joseph8228': 'United States',
#  'anoushka03': 'India',
#  'mielmielloic': 'France',
#  'putinxuilo12': 'Ukraine',
#  'kikijijiaa': 'Pakistan',
#  'mohammadchest': 'Iran',
#  'vua112332': 'Vietnam',
#  'tushar_joshi01': 'India',
#  'crashdash': 'United States',
#  'user7294050292': 'Singapore',
#  'shin-2003': 'South Korea',
#  'imjb11': 'India',
#  'speech9': 'Poland',
#  'futurekalki': 'India',
#  'rayrayrayrayrayrrrraaaayy': 'Philippines',
#  'jimoosh123': 'United States',
#  'asrafislam': 'Bangladesh',
#  'buttercup_aqua': 'India',
#  'starboy-01': 'Kenya',
#  'prettyrosalina': 'United States',
#  'bravo1xq': 'United States',
#  'trip31happy': 'South Korea',
#  'asoto86': 'Mexico',
#  'eddik1981': 'Russia',
#  'sebita_z': 'Uruguay',
#  'zippo3108': 'Indonesia',
#  'jeet_76': 'India',
#  'arnaldurlogi': 'Iceland',
#  'ennnees': 'Türkiye',
#  'abdqllah': 'India',
#  'plazmic008': 'Pakistan',
#  'tcathy': 'United States',
#  'washinotsubasa': 'Germany',
#  'harsh18raj': 'India',
#  'keshav2362': 'India',
#  'robuster99': 'International',
#  'matttfranc': 'Canada',
#  'aintern': 'Japan',
#  'thomasshin84': 'United States',
#  'raidul_x_69': 'Bangladesh',
#  'barray87': 'France',
#  'saudtain': 'Saudi Arabia',
#  'harshadingavale4343343456': 'India',
#  'thec0demaster': 'United States',
#  'ed_chess11': 'Germany',
#  'kingyeyo12': 'Mexico',
#  'radhika_0716': 'India',
#  'rusyth': 'Thailand',
#  'srna_6': 'Saudi Arabia',
#  'emir95s': 'Türkiye',
#  'digjoyboboy': 'Brazil',
#  'tattinscottadams': 'United States',
#  'calcatoghju': 'France',
#  'neilal85': 'Ireland',
#  'mangotour': 'South Korea',
#  'giornogiovanna2006': 'Azerbaijan',
#  'juansalgado04': 'United States',
#  'samuel_armani': 'Bulgaria',
#  'abdullah-31-z-31': 'Türkiye',
#  'lollipoprock': 'France',
#  'mahdiafrasiabi': 'Iran',
#  'papasrcas1936': 'Brazil',
#  'deliaaaa23': 'Spain',
#  'pedroli88': 'Portugal',
#  'msalley': 'Sudan',
#  'adhithya_8': 'India',
#  'hpsoepadmo': 'International',
#  'benyami89': 'Iran',
#  'kaikokun': 'Spain',
#  'sukant324': 'India',
#  'lazyybish': 'US Virgin Islands',
#  'megantron23': 'United States',
#  'pikadasgallaxia': 'Brazil',
#  'maskim18': 'United States',
#  'blacksheep223': 'India',
#  'mohamedaljali': 'Sudan',
#  'simoon12': 'Australia',
#  'vpknight': 'Canada',
#  'jmr000': 'Antigua/Barbuda',
#  'nicklasholm123': 'Denmark',
#  'funnysly': 'France',
#  'mani_shan': 'India',
#  'toverbakel': 'Netherlands',
#  'emikosaw': 'Myanmar',
#  'mastwerr': 'Brazil',
#  'samichaurasiya': 'Nepal',
#  'japogabe': 'Argentina',
#  'gouranga565': 'Bangladesh',
#  'aliyak19': 'Algeria',
#  'ercolorado': 'Argentina',
#  'i-zoro': 'Iraq',
#  'd_u_k_e_01': 'Portugal',
#  'youbakh': 'France',
#  'bdori8': 'Hungary',
#  'adderall-dependent-player': 'US Virgin Islands',
#  'c01092009': 'Vietnam',
#  'chandan_86': 'India',
#  'gianni3333334': 'Italy',
#  'sonzvek': 'France',
#  'mouadabaaqil': 'Morocco',
#  'newplayer169': 'Hong Kong',
#  'nofearxdd': 'Latvia',
#  'vedant_2777': 'India',
#  'shahikant043': 'India',
#  'varunmuppidi': 'India',
#  'aizen_7007': 'India',
#  'whohavethisname': 'Finland',
#  'cipry79': 'Romania',
#  'mcnasty805': 'United States',
#  'apalodima': 'Greece',
#  'rafailmamedow': 'Russia',
#  'dassi55': 'Fiji',
#  'lllll555': 'Philippines',
#  'tham_07': 'Malaysia',
#  'mohammedmetwally92': 'Egypt',
#  'cannonaniim': 'Türkiye',
#  'misspiperade64': 'France',
#  'theguyyoullneverknow': 'India',
#  'fabiana_giuli': 'Italy',
#  'jehdjjse': 'Russia',
#  'nitinsarod': 'India',
#  'carax006': 'Germany',
#  'nicolabaie': 'France',
#  'ilbimbo4896830': 'Italy',
#  'oakwid': 'Brazil',
#  'vinodkumarg': 'India',
#  'neozeratod': 'Ukraine',
#  'saddyboi248': 'Vietnam',
#  'tsullysr': 'United States',
#  'sharpsh00te': 'Canada',
#  'gudsvc': 'Brazil',
#  'aries645': 'Argentina',
#  'nekrion': 'Poland',
#  'paco_913': 'Mexico',
#  'weltonmattos010': 'Brazil',
#  'blayr9053': 'United States',
#  'crisarvie': 'Philippines',
#  'criboch': 'Italy',
#  'insizachamp': 'International',
#  'freezear': 'United States',
#  'mainconfucio': 'Italy',
#  'dhanyavenkat': 'United States',
#  'suvodip007': 'India',
#  'vicentvallsmarti': 'Spain',
#  'psu73': 'United States',
#  'jdw1231': 'United States',
#  'skinnymillonario': 'Ecuador',
#  'chesschrisking': 'Germany',
#  'jssk363': 'United States',
#  'luckylama88939': 'United States',
#  'jpmp1': 'Canada',
#  'sai8812': 'United States',
#  'demonsteiner': 'Tunisia',
#  'faheemshoukat': 'Pakistan',
#  'sahil78rebal': 'India',
#  'ahmad_d70': 'Sudan',
#  'hiro202303': 'Belgium',
#  'rangerrn': 'United States',
#  'checkspearito': 'Mexico',
#  'pbaregan': 'England',
#  'cat_shaped_dog': 'United States',
#  'chawitz2': 'Thailand',
#  'yousef-abbat': 'Saudi Arabia',
#  'amit1690': 'India',
#  'ada9015': 'India',
#  '06rdjl': 'Germany',
#  'maya_3237': 'India',
#  'mbatista911': 'United States',
#  'titaamar': 'Spain',
#  'jalinrabei_69': 'Brazil',
#  'regis275': 'Brazil',
#  'landvogt1': 'Germany',
#  'santhosh442': 'India',
#  'advikmysore': 'United States',
#  'yassinooo213': 'Algeria',
#  'aderlineman': 'International',
#  'epik_gamer69420': 'Philippines',
#  'gokulhanda': 'India',
#  'hoolster': 'Australia',
#  'antoniomenendez': 'Spain',
#  'rva_26_21_01': 'India',
#  'piotrkarnia': 'Poland',
#  'chesskh41': 'United States',
#  'lizzzard704': 'Canada',
#  'gasssx69': 'Indonesia',
#  'eliascoc': 'Argentina',
#  'artdekker': 'Belgium',
#  'ruimca': 'Portugal',
#  'omar1007pok': 'Chile',
#  'handsoffmybishop': 'Canada',
#  'micmaher': 'Egypt',
#  'biragazyapar': 'Türkiye',
#  'vrilgeeker': 'Russia',
#  'gibbo737': 'Australia',
#  'elzer000': 'Philippines',
#  'unknowmaster1234': 'India',
#  'ibrahim11511': 'India',
#  'meysame77': 'Iran',
#  'murtajizmaqsood': 'Pakistan',
#  'spudensky': 'South Africa',
#  'elcin_mursalov': 'Azerbaijan',
#  'lakejumb': 'United Kingdom',
#  'irionjlt': 'United States',
#  'btbremner': 'United Kingdom',
#  'thomas021958': 'Germany',
#  's28091111111': 'India',
#  'bcook0322': 'United States',
#  'akenny2654': 'United Kingdom',
#  'marekmarkus': 'Poland',
#  'sanryovictor': 'Brazil',
#  'figa338': 'Poland',
#  'deepanshus42': 'India',
#  'dimistik': 'Iran',
#  'nitishkg_26': 'India',
#  'rkvcsnrbrt': 'Hungary',
#  'hephaestus265': 'India',
#  'oliverkinggabriel123': 'Philippines',
#  'sahal_hassan': 'India',
#  'ayaanpdinesh': 'India',
#  'nisant11': 'India',
#  'nithin_mu': 'India',
#  'dentech': 'United States',
#  'yashhhhhhh95': 'United States',
#  'solhah': 'Indonesia',
#  'phantomy001': 'India',
#  'karaly7171': 'Hungary',
#  'deathcorps': 'Australia',
#  'azsssbarboza': 'Indonesia',
#  'npgaming2971': 'Vietnam',
#  'itseenz': 'United States',
#  'snowy_bee': 'Bulgaria',
#  'etoyari': 'Spain',
#  'new_pengu1n': 'Saudi Arabia',
#  'bukajek12': 'Poland',
#  'mesi122': 'Vietnam',
#  'plinochallenged': 'United States',
#  'yeayeayeaeya': 'New Zealand',
#  'mustardmaker84': 'United States',
#  'washimjrnrt': 'Bangladesh',
#  'bwill1177': 'United States',
#  'werner_68': 'Israel',
#  'logfriel': 'United Kingdom',
#  'bhaveshraut_79': 'India',
#  'parthpasrija': 'India',
#  'minaboloko': 'Spain',
#  'bychechen': 'Türkiye',
#  'bhishma-chanda': 'India',
#  'fatur11011': 'Indonesia',
#  'phonk_dem': 'Philippines',
#  'jesus712': 'United States',
#  'fitzgerald_24': 'India',
#  'cj0326': 'Philippines',
#  'fakiris123': 'Greece',
#  'phyo159335': 'Myanmar',
#  'magnu-mi': 'Norway',
#  'talk2krvs': 'United States',
#  'teba989': 'Iraq',
#  'mohcine10': 'France',
#  'lakshan3970': 'India',
#  'mauriberna': 'Italy',
#  'zawwintun7': 'United Kingdom',
#  'ishantx2007': 'India',
#  'tonkokg': 'Netherlands',
#  'dssirecho': 'South Africa',
#  'bibhukishandas': 'India',
#  'datthu7': 'India',
#  'shawayush9876': 'India',
#  'transformr03l0x': 'Philippines',
#  'carlcd1032': 'Canada',
#  'ffudyojgio': 'Cambodia',
#  'body836': 'Germany',
#  'ahriman1979': 'United Kingdom',
#  'mixolydio': 'Chile',
#  'ayyextn': 'Australia',
#  'talasuli': 'United States',
#  'r1nir9': 'Russia',
#  'ahmett_aldmr': 'Türkiye',
#  'mu3clec0w1323': 'South Korea',
#  'bezz100': 'Australia',
#  'franflumo': 'Netherlands',
#  'jonc86': 'Brazil',
#  'lipims': 'France',
#  'kalleeko': 'United States',
#  'sysko31': 'France',
#  'ismael2508': 'Mexico',
#  '10prr': 'Japan',
#  'ersalinas18': 'United States',
#  'kunal1849': 'India',
#  'riteshpandu': 'India',
#  'shivrajmalap': 'India',
#  'jgfcjhfcjhtfjht': 'Australia',
#  'dfgjffhj': 'Russia',
#  'aldigaler': 'Indonesia',
#  'ragas090': 'Nepal',
#  'praveen-pachar': 'India',
#  'meenalmaroo': 'India',
#  'favoriteattic': 'Russia',
#  'shadown789': 'Belgium',
#  'sandisuhada': 'Indonesia',
#  'samdenovo': 'Brazil',
#  'so_bad666': 'Myanmar',
#  'wengkail1234': 'Malaysia',
#  'zinrick': 'France',
#  'strykerdav9': 'United States',
#  'sweetcheeks1717': 'Spain',
#  'lhzpx': 'Colombia',
#  'tatatiii': 'Japan',
#  'jerivy10': 'Australia',
#  'gabba-gabba-hey': 'Argentina',
#  'chamuyeithor': 'Chile',
#  'jefjan92': 'Sweden',
#  'sulabeu': 'Bangladesh',
#  'marcos19782016': 'Brazil',
#  'luizfilho0': 'Brazil',
#  'keo-shan': 'France',
#  'ibigshane123': 'United Kingdom',
#  'norbers': 'Italy',
#  'vktinho': 'Brazil',
#  'retrox_ea': 'Argentina',
#  'altamash1611': 'India',
#  'pierre-mcr': 'France',
#  'abhibadal': 'India',
#  'bunnydinh': 'India',
#  'gab-xi': 'Italy',
#  'dorkybug': 'India',
#  'erle1950': 'Germany',
#  'mrfsolefield': 'United Kingdom',
#  'masterjam1203': 'Mexico',
#  'bywen': 'Spain',
#  'ashish14536': 'India',
#  'anorjay': 'Nigeria',
#  'mount_average': 'International',
#  'ponteuspilate': 'Serbia',
#  'olegvnm': 'Czech Republic',
#  'iiiepilok': 'Russia',
#  'samyak_7': 'Nepal',
#  'dianaodb': 'Italy',
#  'omeganer1912': 'Israel',
#  'donjohnmaza': 'United States',
#  'alermooo': 'Ukraine',
#  'natmoua': 'United States',
#  'subin1023': 'India',
#  'matanya457': 'Israel',
#  'lucasguilhermexx': 'Brazil',
#  'dingle_bees': 'United States',
#  'quiquedrin': 'Spain',
#  'blaqkinkade': 'Nigeria',
#  'cyclistmass': 'United States',
#  'andreitanasov': 'Moldova',
#  'xavierrenk': 'United States',
#  'bylek3': 'Poland',
#  'roro1918': 'India',
#  'franstruffolino': 'Argentina',
#  'playerzxx': 'Türkiye',
#  'msviroy': 'India',
#  'gigi3la': 'Georgia',
#  'mikabety2012': 'Brazil',
#  'bobkobeissi': 'Lebanon',
#  'ankush9897': 'India',
#  'alban1214': 'Kosovo',
#  'mircoalessandrini': 'Italy',
#  'abdullayef017': 'Azerbaijan',
#  'edu55554': 'Brazil',
#  'bandex256': 'Uganda',
#  'tamermansi': 'Egypt',
#  'serginhociclone': 'Brazil',
#  'stamphybroff': 'United Kingdom',
#  'rijul0404': 'India',
#  'peter_nabil': 'Egypt',
#  'luckymugen': 'Italy',
#  'grid_12': 'Ukraine',
#  'amibm': 'United Kingdom',
#  'simon_zehn': 'Germany',
#  'kazuhanezuko': 'Vietnam',
#  'lebosky': 'Catalonia',
#  'supto2023': 'Bangladesh',
#  'rafafm98': 'Brazil',
#  'emailterribile': 'Italy',
#  'samyscoob': 'France',
#  'szemil_gg': 'Poland',
#  'a7madtayyem': 'Palestine',
#  'fimanave': 'Israel',
#  'salvatore_gianfagna': 'Italy',
#  'jonasmevel': 'France',
#  'pablo-j-dc': 'Spain',
#  'md73008': 'United States',
#  'amoregarden': 'Nigeria',
#  'sibuabraham': 'India',
#  'loudwhisper123': 'Nigeria',
#  'harsh_all': 'South Africa',
#  'mrevivo': 'Israel',
#  'aminec44': None,
#  'fakepopsmoke': 'France',
#  'pablo_fx': 'Spain',
#  'berlinmax': 'Germany',
#  'adinath007': 'India',
#  'bfnikai': 'Philippines',
#  'paveltopg': 'Russia',
#  'lkylny379': 'Egypt',
#  'jibbidy7': 'United States',
#  'silviaari': 'Bulgaria',
#  'marry2596': 'Pakistan',
#  'multiqalbiadi': 'Indonesia',
#  'russell_uy': 'Philippines',
#  'shantokhan74': 'Bangladesh',
#  'ali-valbuena': 'Venezuela',
#  'bunclebarrancs': 'Spain',
#  'fazarxd': 'Indonesia',
#  'aaliyaarora': 'Germany',
#  'witesik': 'Poland',
#  'afifafifafif': 'Malaysia',
#  'twilighthaha': 'Philippines',
#  'ranaraman': 'India',
#  'i_sum': 'South Korea',
#  'lesleymambwe': 'Zambia',
#  'skonfort': 'Tunisia',
#  'granifol': 'United States',
#  'seven960': 'Mexico',
#  'parevechulent': 'United States',
#  'albiladi': 'Saudi Arabia',
#  'minkaungst': 'Myanmar',
#  'hertizord': 'United Kingdom',
#  'mohamedeid1234884847': 'Egypt',
#  'herobot01': 'South Korea',
#  'mityadegurchaff': 'Russia',
#  'r0or0o': 'Finland',
#  'laxman1956': 'India',
#  'gauravarora2001': 'India',
#  'seti71': 'United Kingdom',
#  'studermarc': 'Switzerland',
#  'pepe4000sgf': 'Mexico',
#  'sergiossssss': 'Ukraine',
#  'solalteng': 'United States',
#  'xaviphone': 'France',
#  'sigaso': 'Argentina',
#  'jwadinho5': 'Iraq',
#  'churchmom': 'United States',
#  'marianlev': 'Ukraine',
#  'checkmate_211': 'India',
#  'hussien_farouk': 'Egypt',
#  'jackbikar': 'Belgium',
#  'antoine_p57': 'France',
#  'abelbock': 'Italy',
#  'bazingggaaaa': 'India',
#  'deplayted': 'Russia',
#  'jakov837': 'Israel',
#  'fran4ways': 'South Africa',
#  'pctyk': 'International',
#  'momo19811': 'United Kingdom',
#  'olushol': 'Nigeria',
#  'mayck2811': 'Brazil',
#  'th3pers0n': 'United States',
#  'maverack': 'Ghana',
#  'kadarkaraiselvam': 'India',
#  'oleg500qm': 'Seychelles',
#  'duxducisduce': 'Italy',
#  'fabiocacarioca': 'Italy',
#  'extra_thicc1029': 'Australia',
#  'jeabkaewlod2010': 'Netherlands',
#  'stvndouthim': 'United States',
#  'aditrap': 'Vatican City',
#  'ekouti': 'Singapore',
#  'kung4ukimaz': 'United States',
#  'rizzz13': 'Indonesia',
#  'kanishkamohapatra': 'India',
#  'vivek_02': 'European Union',
#  'tuzzinduk13': 'Brazil',
#  'flopchess1111': 'Australia',
#  'diceychesd': 'Nigeria',
#  'unbreakable1020': 'India',
#  'lebzin10': 'South Africa',
#  'kabuthitam': 'Indonesia',
#  'gospodintodorov42': 'Bulgaria',
#  'natalia2205': 'Poland',
#  'tomaustin1': 'France',
#  'ferbigga132': 'Pakistan',
#  'chesstyme1': 'United States',
#  'maximuswagimus': 'Japan',
#  'amir_haji': 'Iran',
#  'luka_skywalker7': 'Finland',
#  'zaza2013572': 'United States',
#  'vroasatryan1221': 'Armenia',
#  'kurtlegrand': 'Netherlands',
#  'rdbrnco': 'Portugal',
#  'nsc_roberto': 'Brazil',
#  'atsantos17': 'Brazil',
#  'nachimixtou': 'Chile',
#  'pranav21127': 'India',
#  'ben_lakra': 'India',
#  'alavellana': 'United States',
#  'hoodedowl': 'Netherlands',
#  'dornocu': 'Brazil',
#  'robo-knight': 'United States',
#  'kp_physics': 'India',
#  'adrza': 'Venezuela',
#  'jakob-g': 'Germany',
#  'huligun2009': 'South Korea',
#  'brenflan': 'Ireland',
#  'abhi9948': 'India',
#  'quicksilverz95': 'United States',
#  'atha2456': 'India',
#  'yashbaghel1729': 'India',
#  'bibek3108': 'India',
#  'chrisdaniel2015': 'Australia',
#  'wonderia123': 'Bangladesh',
#  'ig_deveshwar8979': 'India',
#  'ajmioussamafg': 'Tunisia',
#  'fcberlin': 'Argentina',
#  'arsul1': 'Norway',
#  'king_faizan786': 'United Kingdom',
#  'ryuki_94': 'Japan',
#  'dumm_human': 'India',
#  'azrah45': 'Canada',
#  'federob3': 'Italy',
#  'shadow-karim': 'Algeria',
#  'yukansenshi': 'India',
#  'pkh0404': 'India',
#  'yashy09': 'India',
#  'noctisspassky': 'Indonesia',
#  'jamoes21': 'Germany',
#  'obbyob': 'El Salvador',
#  'lulunba1': 'Canada',
#  'noriakiakakyoinlerolero': 'India',
#  'raedrafikwasfy': 'Egypt',
#  'f4k4pp4': 'Poland',
#  'darshan-kakanur': 'India',
#  'liam_addo': 'United Kingdom',
#  'jeandruk': 'France',
#  'pattycake91': 'United Kingdom',
#  'ledapperduck': 'United States',
#  'shfdfhji': 'France',
#  'nuttywun': 'New Zealand',
#  'x-0971292412': 'International',
#  'gh_ost22': 'United Kingdom',
#  'mokaddm': 'United States',
#  'rob_khaos': 'United States',
#  'dagoneber': 'Germany',
#  'floechec92': 'France',
#  'kerolosashraf1': 'Egypt',
#  'mrhall1923': 'United States',
#  'zendobenzo': 'Spain',
#  'satis2': 'Cyprus',
#  'ppw25': 'Czech Republic',
#  'robertopinguim': 'Brazil',
#  'jorgecarlsen1': 'Chile',
#  'k4sirg4': 'Türkiye',
#  'asnejuve': 'Norway',
#  'oliveryujiro_123': 'Türkiye',
#  'jabinelin': 'Dominican Republic',
#  'andrelbmoog': 'Brazil',
#  'webbeast3': 'Egypt',
#  'aaronmo13': 'United States',
#  'marcithebishop': 'Hungary',
#  'masterbaiter_12': 'Kazakhstan',
#  'nigzouz': 'Canada',
#  'v_4o': 'Iraq',
#  'eason8': 'Australia',
#  'rayantr': 'Lebanon',
#  'emilozio90': 'Italy',
#  'skynet0_0': 'France',
#  'deaglemoon': 'Italy',
#  'calinbaros': 'Romania',
#  'chesseteer1': 'Nigeria',
#  'goldbybe': 'United Kingdom',
#  'arnavkarekar69': 'India',
#  'wainadoiwonderman': 'Fiji',
#  'benjaminvmarques': 'Brazil',
#  'spoonfeed': 'United Kingdom',
#  'sanjay97297': 'India',
#  'pedoslayerr': 'Jordan',
#  'rishii_183': 'India',
#  'lluisjduran': 'Catalonia',
#  'dumbman_101': 'India',
#  'zangygalaqtioni': 'Georgia',
#  'alexisknk': 'France',
#  'nathan1234452': 'United Kingdom',
#  'spaslba': 'Italy',
#  'mughalspy': 'India',
#  'yusefarghand': 'Iran',
#  'mclenovo': 'Australia',
#  'arkabanerjee381': 'India',
#  'unprofesionally': 'Vietnam',
#  'abhi_shekkkk': 'India',
#  'qaidana': 'Kazakhstan',
#  'chbb0': 'Brazil',
#  'asfy6': 'Israel',
#  'cbfa17': 'Afghanistan',
#  'stewiefm': 'Spain',
#  'its_ab_555': 'India',
#  'muhannad30': 'Saudi Arabia',
#  'jijiholoo': 'Australia',
#  'oarabilefidel': 'South Africa',
#  'mumiaabu': 'United States',
#  'arcangelo54': 'Italy',
#  'rmz704t': 'Italy',
#  'florin_id': 'Romania',
#  'stubb173': 'Norway',
#  'mystic-mo': 'Germany',
#  'kontolodonberanakmega': 'Indonesia',
#  'paolosassi': 'Italy',
#  's3odplayz': 'Saudi Arabia',
#  'pattyrick808': 'United States',
#  'ken051807': 'Philippines',
#  'unveilcloth': 'Philippines',
#  'unknownmercthethird': 'South Africa',
#  'wearytwo': 'United States',
#  'leonardopratess': 'Brazil',
#  'sethalethicus': 'United States',
#  'timmymac42': 'United States',
#  'takehirotomiyasu': 'Japan',
#  'braca911': 'Mexico',
#  'hpc2sweet': 'United States',
#  'lord-ao': 'Bhutan',
#  'tacj47': 'United States',
#  'ryouasukan': 'Vietnam',
#  'skinnydog1973': 'England',
#  'fahadarekar': 'India',
#  'kakotov': 'Chile',
#  'nafihmuhammed4': 'India',
#  'opidet': 'Germany',
#  'kingadam231108': 'Egypt',
#  'lowskillme': 'Russia',
#  'elhassen03': 'Tunisia',
#  'finsbury_park': 'United Kingdom',
#  'sonerpetek17': 'Türkiye',
#  'jeanaymart': 'France',
#  'bigsockss': 'United States',
#  'yeid947483': 'Peru',
#  'lonely_chopstick': 'Japan',
#  'aiglesiasm': 'Spain',
#  'killerkingyt': 'Iran',
#  'elvetius': 'Italy',
#  'erik7283': 'Mexico',
#  'sergeychess23': 'Ukraine',
#  'chessscrofa': 'International',
#  'jo0kii': 'Egypt',
#  'ddxirvx': 'Mexico',
#  'colorfularmy': 'United States',
#  'gm-samyak-08': 'India',
#  'cuikanne': 'United Kingdom',
#  'gondon_1': 'Ukraine',
#  'devam303': 'India',
#  'nazmazed': 'United States',
#  'bepirocia': 'Italy',
#  'dieg84': 'France',
#  'jxyuun': 'Germany',
#  'dravyajha': 'India',
#  'a_kid_named_alexander': 'Philippines',
#  'potatosunglasses': 'Bangladesh',
#  'rockrax': 'France',
#  'uctien': 'Vietnam',
#  'jordanaluis': 'Spain',
#  'zaherarraf': 'Israel',
#  'yousef3011': 'Egypt',
#  'jerryjo91': 'Egypt',
#  'monkeymyster': 'United Kingdom',
#  'gmalfomay2': 'Spain',
#  'markptc': 'United States',
#  'belanov03': 'France',
#  'sikooooooooooooooo': 'Egypt',
#  'jubbeee': 'Australia',
#  'tharwat13': 'Egypt',
#  'wwendyyj': 'Switzerland',
#  'yamir49': 'Chile',
#  'yassine_mj9': 'Morocco',
#  '8point4': 'France',
#  'md17175': 'India',
#  'pinkcypher': 'United Kingdom',
#  'kramar-urii': 'Russia',
#  'capizaguirre': 'Mexico',
#  'willywonkahd': 'United States',
#  'geyzuski1111': 'India',
#  'x-7404271567': 'International',
#  'nachtvampir': 'Germany',
#  'eiderlof': 'France',
#  'hiram721': 'Mexico',
#  'kenyi2807': 'Peru',
#  ...}

# %%
gold_df['opponent_country'] = gold_df['opponent'].map(opponent_country_map)
gold_df[gold_df['opponent_country'].isna()]
# Out:
#                                       uuid    player  player_elo  \
# 62    0aac6179-c9ef-11ee-a1ad-f4d4b901000f  ahmedbdk         270
# 752   08f7c962-9ddb-11ef-9df8-6cfe544c0428  ahmedbdk         735
# 2056  c192cd87-0c3c-11f0-8bb9-5e214901000f  ahmedbdk         899
# 2062  e6a177eb-0c3f-11f0-86fc-5f149301000f  ahmedbdk         932
# 2512  91de055c-207e-11f0-91c5-00fb3e01000f  ahmedbdk         745
# 2515  3194237a-2080-11f0-98a9-a0062d01000f  ahmedbdk         728
# 2518  86cdc8e6-20e8-11f0-b127-fd9f9e01000f  ahmedbdk         752
# 2524  513cc0a9-2158-11f0-b127-fd9f9e01000f  ahmedbdk         760
# 2554  b050c8f2-228e-11f0-8b1f-9d3a9401000f  ahmedbdk         754
# 2611  43acd8cc-2367-11f0-b127-fd9f9e01000f  ahmedbdk         551
# 2617  be2b1248-2368-11f0-98a9-a0062d01000f  ahmedbdk         581
# 2645  94f125bc-242f-11f0-bef9-b481e001000f  ahmedbdk        1049
# 2815  28cf96ee-453d-11f0-bb81-5d933701000f  ahmedbdk         840
# 2860  1868c6ab-4892-11f0-acd2-6f075a01000f  ahmedbdk         808
# 2872  cd7166a9-6e2d-11f0-9082-b5105e01000f  ahmedbdk         630
# 2920  3bdf4254-6ef7-11f0-8c00-fdf47001000f  ahmedbdk         714
# 2944  ec8b6260-6f11-11f0-a782-67c26501000f  ahmedbdk         718
#
#              opponent  opponent_elo player_color opponent_color      result  \
# 62         anaskufche           293        black          white  checkmated
# 752          aminec44           337        white          black         win
# 2056      dscosta2001           874        black          white         win
# 2062        jezmorgan           962        white          black    resigned
# 2512          rls1229           780        white          black    resigned
# 2515         sobakoeb           761        white          black    resigned
# 2518         jakasona           738        black          white         win
# 2524      kene_chukwu           783        black          white    resigned
# 2554     starfish1037           750        black          white    resigned
# 2611      igalvarenga           552        white          black    resigned
# 2617        benato456           546        black          white         win
# 2645  mathwsdementius          1037        black          white         win
# 2815         vanfranz           839        white          black    resigned
# 2860    nathanchesnut           804        white          black    resigned
# 2872         crispo20           619        black          white         win
# 2920       mtnbiker99           732        black          white     timeout
# 2944         tavzara3           663        black          white         win
#
#      time_class time_control  \
# 62        rapid          600
# 752       rapid          600
# 2056      rapid          600
# 2062      rapid          600
# 2512      blitz          180
# 2515      blitz          180
# 2518      blitz          180
# 2524      blitz          180
# 2554      blitz          180
# 2611     bullet         60+1
# 2617     bullet         60+1
# 2645      rapid          600
# 2815      blitz        180+2
# 2860      blitz          180
# 2872     bullet         60+1
# 2920     bullet         60+1
# 2944     bullet         60+1
#
#                                                 opening  rated  \
# 62                            Kings-Pawn-Opening-1...e5   True
# 752       Queens-Gambit-Declined-Chigorin-Defense-3.Nc3   True
# 2056  Kings-Pawn-Opening-Kings-Knight-Konstantinopol...   True
# 2062                              Three-Knights-Opening   True
# 2512  Pirc-Defense-Modern-Defense-Geller-System-2......   True
# 2515          Queens-Pawn-Opening-Krause-Variation-3.e3   True
# 2518                Queens-Pawn-Opening-1...d5-2.e3-Nf6   True
# 2524                Giuoco-Piano-Game-Four-Knights-Game   True
# 2554                                       Colle-System   True
# 2611                    French-Defense-Knight-Variation   True
# 2617  Four-Knights-Game-Scotch-Variation-Accepted-5....   True
# 2645  Giuoco-Piano-Game-Giuoco-Pianissimo-Variation-...   True
# 2815  Giuoco-Piano-Game-Giuoco-Pianissimo-Italian-Fo...   True
# 2860          French-Defense-Kings-Indian-Attack-2...d5   True
# 2872               Giuoco-Piano-Game-4.O-O-Nf6-5.Nc3-d6   True
# 2920                                       Kings-Gambit   True
# 2944    Colle-System-Anti-Colle-Variation-4.c4-e6-5.Nc3   True
#
#             end_datetime player_accuracy opponent_accuracy  \
# 62   2024-02-12 21:51:49            None              None
# 752  2024-11-08 14:14:34            None              None
# 2056 2025-03-29 01:31:15            None              None
# 2062 2025-03-29 01:54:12            None              None
# 2512 2025-04-23 20:11:02            None              None
# 2515 2025-04-23 20:20:19            None              None
# 2518 2025-04-24 08:49:18            None              None
# 2524 2025-04-24 22:07:57            None              None
# 2554 2025-04-26 11:08:05            None              None
# 2611 2025-04-27 12:58:35            None              None
# 2617 2025-04-27 13:11:37            None              None
# 2645 2025-04-28 13:00:22            84.0             76.03
# 2815 2025-06-09 14:23:22            None              None
# 2860 2025-06-13 20:12:17            None              None
# 2872 2025-07-31 16:47:18            None              None
# 2920 2025-08-01 16:50:08            None              None
# 2944 2025-08-01 20:01:51            None              None
#
#                                                url opponent_country
# 62    https://www.chess.com/game/live/101260102402             None
# 752   https://www.chess.com/game/live/124813796773             None
# 2056  https://www.chess.com/game/live/136786975948             None
# 2062  https://www.chess.com/game/live/136787384904             None
# 2512  https://www.chess.com/game/live/137712712776             None
# 2515  https://www.chess.com/game/live/137713063474             None
# 2518  https://www.chess.com/game/live/137728200248             None
# 2524  https://www.chess.com/game/live/137752650772             None
# 2554  https://www.chess.com/game/live/137804600704             None
# 2611  https://www.chess.com/game/live/137842242354             None
# 2617  https://www.chess.com/game/live/137842549658             None
# 2645  https://www.chess.com/game/live/137876726916             None
# 2815  https://www.chess.com/game/live/139394349752             None
# 2860  https://www.chess.com/game/live/139559310380             None
# 2872  https://www.chess.com/game/live/141329484852             None
# 2920  https://www.chess.com/game/live/141368130356             None
# 2944  https://www.chess.com/game/live/141374300212             None

# %%
output_path = f"chess_games_{username}_gold.csv"

gold_df.to_csv(
    output_path,
    index=False,
    encoding="utf-8"
)

# %%
archives[-1]
# Out:
# 'https://api.chess.com/pub/player/ahmedbdk/games/2025/09'
