# %%
import pandas as pd
import numpy as np
import requests
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; ChessDataBot/1.0)"
}

def get_archives(username):
    url = f"https://api.chess.com/pub/player/{username}/games/archives"
    response = requests.get(url, headers=HEADERS)

    if response.status_code != 200:
        raise Exception(f"Erreur API archives: {response.status_code}")

    return response.json()["archives"]

# %%
def get_player_country(username):
    if not username:
        return None

    try:
        url = f"https://api.chess.com/pub/player/{username}"
        r = requests.get(url, headers=HEADERS, timeout=10)

        if r.status_code != 200:
            return None

        data = r.json()
        country_url = data.get("country")

        if not country_url:
            return None

        return country_url.split("/")[-1]

    except Exception:
        return None

# %%
def get_games_from_archive(archive_url):
    response = requests.get(archive_url, headers=HEADERS)

    if response.status_code != 200:
        raise Exception(f"Erreur API games: {response.status_code}")

    return response.json()["games"]

# %%
def parse_games(games):
    table = []

    for game in games:
        row = {
            "uuid": game.get("uuid"),
            "url": game.get("url"),
            "white": game["white"]["username"],
            "black": game["black"]["username"],
            "result_white": game["white"]["result"],
            "result_black": game["black"]["result"],
            "white_elo": game["white"]["rating"],
            "black_elo": game["black"]["rating"],
            "time_control": game.get("time_control"),
            "time_class": game.get("time_class"),
            "rated": game.get("rated"),
            "eco": game.get("eco"),
            "accuracy_white": game.get("accuracies", {}).get("white"),
            "accuracy_black": game.get("accuracies", {}).get("black"),
            "pgn": game.get("pgn"),
            "end_time": game.get("end_time")
        }

        table.append(row)

    return table

# %%
username = "ahmedbdk"
username =username.lower()
# 1. récupérer les archives
archives = get_archives(username)

games = []

# 2. Parcourir toutes les archives
for archive in archives:
    # 3. récupérer les parties
    games += get_games_from_archive(archive)
    

# 4. parser les parties dans un tableau
table = parse_games(games)

# 5. résultat
print(f"{len(table)} parties récupérées")
# Out:
# 3168 parties récupérées

# %%
bronze_df = pd.DataFrame(table)

# %%
silver_df = bronze_df.copy()

# %%
silver_df['white'] = silver_df['white'].str.lower()
silver_df['black'] = silver_df['black'].str.lower()
silver_df[['accuracy_white','accuracy_black']] = silver_df[['accuracy_white','accuracy_black']].fillna('None')
silver_df['end_datetime'] = pd.to_datetime(bronze_df['end_time'], unit='s')
silver_df['rated'] = silver_df['rated'].astype(bool)
silver_df[['white_elo','black_elo']] = silver_df[['white_elo','black_elo']].astype(int)
silver_df = silver_df.drop_duplicates(subset='uuid')

# %%
gold_df = silver_df.copy()

# %%
gold_df['player'] = username
gold_df['opponent'] = np.where (
    (username == gold_df ['white']),
     gold_df['black'],
     gold_df['white'])
gold_df['result'] = np.where (
    (username == gold_df['white']),
    gold_df['result_white'],
    gold_df['result_black'])
gold_df['player_elo'] = np.where (
    (username == gold_df ['white']),
    gold_df['white_elo'],
    gold_df['black_elo'])
gold_df['opponent_elo'] = np.where (
    (username == gold_df ['white']),
    gold_df['black_elo'],
    gold_df['white_elo'])
gold_df['player_color'] = np.where (
    (username == gold_df['white']),
    'white',
    'black')
gold_df['opponent_color'] = np.where (
    (username == gold_df['white']),
    'black',
    'white')
gold_df['player_accuracy'] = np.where (
    (username == gold_df['white']),
    gold_df['accuracy_white'],
    gold_df['accuracy_black'])
gold_df['opponent_accuracy'] = np.where (
    (username == gold_df['white']),
    gold_df['accuracy_black'],
    gold_df['accuracy_white'])

gold_df['opening'] = gold_df['eco'].str.split('openings/').str[1]

# %%
new_order = ['uuid','player','player_elo','opponent','opponent_elo','player_color','opponent_color','result','time_class','time_control','opening','rated','end_datetime','player_accuracy','opponent_accuracy','url']
gold_df = gold_df[new_order]

# %%
unique_opponents = gold_df['opponent'].dropna().unique()
len(unique_opponents)
# Out:
# 3023

# %%
opponent_country_map = {}

with ThreadPoolExecutor(max_workers=15) as executor:
    results = executor.map(get_player_country, unique_opponents)

    for opponent, country in tqdm(
        zip(unique_opponents, results),
        total=len(unique_opponents),
        desc="Fetching opponent countries"
    ):
        opponent_country_map[opponent] = country
# Out:
# Fetching opponent countries: 100%|█████████████████████████████████████████████████| 3023/3023 [15:27<00:00,  3.26it/s]

# %%
opponent_country_map
# Out:
# {'houssemiladi': 'TN',
#  'danyagggy': 'KZ',
#  'dalleji4real': 'FR',
#  'stilllearning81': 'US',
#  'azzipi': 'TH',
#  'piyushbhatia2': 'IN',
#  'mneimar1': 'MA',
#  'valle546': 'DE',
#  'bolagato3': 'BR',
#  'fco_lazcano-inactive': 'CL',
#  'zimians': 'ZA',
#  'selvadarshu': 'MY',
#  'vyom1401': 'SE',
#  'jugobetrugo1223': 'DE',
#  'peterbennett04': 'GB',
#  'tiwana1777': 'CA',
#  '5439hfkfo': 'CN',
#  'chess12345612345': 'GB',
#  'toomag': 'IR',
#  'ravenous_demon1134': 'US',
#  'shorouk02': 'IT',
#  'lyphu': 'VN',
#  'chessearner555': 'IN',
#  'riderp82': 'IN',
#  'kchessboard': 'DZ',
#  'eavvbb': 'IT',
#  'shonathebest': 'CA',
#  'miagame': 'KP',
#  'mayar9998': 'SA',
#  'mmaalik01': 'CA',
#  'gagimirka': 'RS',
#  'patrikfelix': 'SK',
#  'dr7yaya': 'IN',
#  'zurye': 'MX',
#  'mrhamidrezaa': 'IR',
#  'fisu1330': 'UY',
#  'geedi23': 'SE',
#  'tatan9402': 'CO',
#  'hiradanish': 'US',
#  'phoenixak47': 'BD',
#  'iwilldefeatadi': 'IN',
#  'ice_tain': 'KR',
#  'f1kj5n1': 'SG',
#  'virunbhai94': 'IN',
#  'nerthee': 'GB',
#  'perejoan03': 'ES',
#  'crowomagnifico': 'BR',
#  'sierrasierra1': 'IN',
#  'johnny123chess': 'ET',
#  'anaskufche': 'MA',
#  'khagger': 'US',
#  'ralphrizzy': 'US',
#  'gbrshthrpwd': 'FR',
#  't3mmm': 'PH',
#  'hubertkusal': 'PL',
#  'peter14264': 'IN',
#  'racecar_0013': 'US',
#  'princessenora': 'FR',
#  'mozzo223': 'IT',
#  'a_karlaaaaal': 'PK',
#  'julesrhys': 'AU',
#  'l00rdinho': 'BR',
#  'nirro26': 'FR',
#  'tomasharcar': 'GB',
#  'brabusg8': 'UA',
#  'thao2412': 'VN',
#  'kamilkazgrilka': 'PL',
#  'kenngaongo2509': 'VN',
#  'yossefmagdy682012': 'EG',
#  'joanne1300': 'US',
#  'svnaik': 'IN',
#  'nottoday006666': 'IN',
#  'jeanyin': 'ES',
#  'javi_18ct': 'ES',
#  'salih_8': 'TR',
#  'djeb987': 'FR',
#  'xxhensxx': 'XW',
#  'itstinkerbelle': 'PH',
#  'astrothechessking': 'US',
#  'woo5192': 'US',
#  'zacc1997': 'US',
#  'charu_1991': 'IN',
#  'deadlygamerog': 'IN',
#  'vicenby': 'ES',
#  'david_leanca': 'MD',
#  'ahmed_goger': 'RO',
#  'rizwanahmed12': 'PK',
#  'jamo023': 'GB',
#  'luffykingofthpirate': 'IN',
#  'totsuka19': 'BR',
#  'puv71': 'ES',
#  'duasweety': 'AE',
#  'shashi_yadav21': 'IN',
#  'rlklibra': 'FR',
#  'johan073081': 'LU',
#  'leonp98': 'GB',
#  'ceddie11': 'DE',
#  'olisnaer': 'IS',
#  'cesticles': 'IE',
#  'sporehorizont': 'AT',
#  'y7t': 'US',
#  'itz_me_abid': 'BD',
#  'zeynep3441': 'TR',
#  'aeduardozrx': 'BR',
#  'eureka7astral': 'US',
#  'voldemort1196': 'DE',
#  'jitesh107': 'IN',
#  'minzdu05': 'FR',
#  'mazimn': 'MY',
#  '7ussein_e-aljamal': 'CA',
#  'sarahbail03': 'XX',
#  'shusher122shush': 'SE',
#  'kimngan01112009': 'VN',
#  'icy2blizz': 'US',
#  'elfrine': 'US',
#  'shiiiiii_22': 'IN',
#  'redqkc19': 'GB',
#  'jelias74': 'CO',
#  'faiqzainal': 'MY',
#  'omarr10x': 'BA',
#  'ejmejmejmejm': 'US',
#  'luccas220': 'BR',
#  'fiestapotatoes': 'US',
#  'dstrydavid': 'DE',
#  'dbapfa': 'ES',
#  'mushucc': 'CL',
#  'justbe123123': 'GB',
#  'isa_lemuar': 'IT',
#  'shazeeb123': 'NO',
#  'julien3212': 'FR',
#  'elcioneoliveira': 'BR',
#  '75re': 'IT',
#  'kevineckstein': 'TT',
#  'garyp55': 'US',
#  'iycrtgtfo': 'US',
#  'emreckmk20': 'TR',
#  'nachiket_kamdar2008': 'IN',
#  'celinafr': 'AT',
#  'plsletmeplayplspls': 'IT',
#  'indrakarki123': 'NP',
#  'jbsoloman5000': 'ZA',
#  'ikoav': 'IT',
#  'charlysgambit': 'AT',
#  'severochek': 'UA',
#  'dertlok': 'US',
#  '8_camilo_2': 'MX',
#  'amaury67000': 'FR',
#  'netsi11': 'ET',
#  'daningalvao': 'BR',
#  'satyam4392': 'IN',
#  'jmmartinavila': 'ES',
#  'schauhan7': 'IN',
#  'denofr': 'TR',
#  'sshhh2004': 'SA',
#  'naserpouyan': 'IR',
#  'charcuterieee': 'AU',
#  'elephant40000': 'CA',
#  'chessgodkerr': 'US',
#  'owentheawesome4422': 'US',
#  'blackgod717': 'US',
#  'thekingisbackkkkk': 'KP',
#  'hundal94': 'CA',
#  'itsjr20': 'US',
#  'mayssenid': 'TN',
#  'vladdraculaaa': 'IN',
#  'titanic_pawntiff': 'US',
#  'ply1974': 'NL',
#  'chaulin_is_chaulin': 'BR',
#  'wagioo': 'EG',
#  'goosterblack': 'FR',
#  'ranvijay-1993': 'IN',
#  'melaso56': 'US',
#  'rynerich': 'US',
#  'hsnyr': 'PK',
#  'frvk123': 'IN',
#  'kieutrang3454': 'VN',
#  'dybelton': 'US',
#  '1011lpql': 'EC',
#  'happybob21': 'GB',
#  'mo0rra': 'US',
#  'dady11': 'RO',
#  'eltoney': 'EG',
#  'saraj26': 'IQ',
#  'umisnzjzzn': 'IN',
#  'manolitoqk': 'ES',
#  'sanspixel': 'US',
#  'paurupablo': 'CA',
#  'squallexino': 'UA',
#  'blacktearr': 'PL',
#  'ashokv9': 'IN',
#  'mirzle': 'AU',
#  'psahmed128555': 'TN',
#  'winmarta': 'GB',
#  'soiney2023': 'BR',
#  'dankdavetharave': 'GB',
#  'ju_ng67': 'FI',
#  'nscag': 'AU',
#  'bahaehh': 'MA',
#  'sakshigadgil': 'IN',
#  'sullyc101': 'NL',
#  'victormasacree': 'VE',
#  'math_y0u': 'US',
#  'mrgrange': 'US',
#  'autcarlsen': 'AT',
#  'thekidlaroi_27': 'US',
#  'malowski1985': 'IM',
#  'uhhdalg': 'PH',
#  'x-8833833077': 'XX',
#  'misters128': 'SK',
#  'ashish7874': 'IN',
#  'archanavellore': 'IN',
#  'champion007xd': 'IN',
#  'noobwarrior69': 'NG',
#  'khaleel000': 'AR',
#  'smon1981': 'GB',
#  'woosungwarrior': 'US',
#  'el3nkeer': 'EG',
#  'edbrooook': 'PT',
#  'suresh-90': 'IN',
#  'amanop567': 'IN',
#  'doctorshiv13': 'IN',
#  'tone4321': 'US',
#  'aarab_bhai_on_top': 'IN',
#  'prernachandani': 'IN',
#  'ani6780': 'IN',
#  'farawayfromyoua': 'US',
#  'lukastmd': 'PL',
#  'bulatov24': 'RU',
#  'bala020201': 'IN',
#  'ranjana1972': 'IN',
#  'romanfrolov': 'RU',
#  'anatoliy7105': 'RU',
#  'vincent7891': 'IN',
#  'yusufgzkck': 'TR',
#  'kmong012': 'IN',
#  'amr_hassan12347': 'IL',
#  'silviacre': 'EC',
#  'jb_313': 'US',
#  '9999lv': 'KR',
#  'el_pollon01': 'SV',
#  'youngdjango98': 'GB',
#  'mohitsolo_x': 'IN',
#  'babonibf': 'IN',
#  'din_loyd': 'IN',
#  'sweart18': 'PT',
#  'abdullahf15v': 'SA',
#  'ostronow666': 'DE',
#  'fathiru': 'ID',
#  'juanillo81': 'ES',
#  'kimyoungjo222': 'KR',
#  'parmod2023': 'IN',
#  'vanderstorg': 'FR',
#  'gefkouk': 'FR',
#  'thewhiteberman': 'MA',
#  'rachit_2105': 'IN',
#  'yash4dubariya': 'IN',
#  'yourlovemelody': 'AE',
#  'ashaleag': 'IN',
#  'iqsssss': 'IN',
#  'djdhdhshshshshdhdhrhrhrhr': 'IN',
#  'swifzzx': 'BR',
#  'mustidoc777': 'IN',
#  'dutrinha0': 'BR',
#  'kashishkim': 'CA',
#  'athuz91': 'IN',
#  'buyanaakhuu': 'MN',
#  'akkubhai26': 'IN',
#  'komiljon1307': 'UZ',
#  'ambberlab': 'XX',
#  'meguf': 'US',
#  'nikib42': 'GB',
#  'sebastian1498': 'CO',
#  'lathekeon': 'TH',
#  'omar535o': 'EG',
#  'siri-jdma': 'MX',
#  'capolupi': 'IT',
#  'lakhan9999': 'IN',
#  'martsoni': 'ES',
#  'smv3': 'FI',
#  'hdhajbdvd': 'IN',
#  'dudapirangx': 'ID',
#  'pipipicasso': 'SG',
#  'devthakuri': 'NP',
#  'mkjha1': 'IN',
#  'fiejdi': 'PL',
#  '0o0whatings': 'IN',
#  'plip612': 'KR',
#  'nithish772007': 'IN',
#  'garrettisok': 'US',
#  'louisr27': 'GB',
#  'drzed3': 'XX',
#  'rocuma': 'MX',
#  'zaid707': 'MA',
#  'ghostblue93': 'FR',
#  'osamaalking': 'EG',
#  'dil_283': 'IN',
#  'globule_bcn': 'ES',
#  'sankarsahoo': 'IN',
#  'atauriko': 'XB',
#  'kooky53': 'IN',
#  'sinahadadi': 'IR',
#  'histoevil': 'XX',
#  'aroojkiran': 'PK',
#  'lakeyj44': 'US',
#  'supreethanaveen': 'IN',
#  'ibrahimelagamy74': 'EG',
#  'sholett': 'RU',
#  'geraldina1224': 'AL',
#  'bigmoth00': 'BR',
#  'yeonseong12345gmailcom': 'KR',
#  'jetlosjjw': 'PH',
#  'notfall07': 'US',
#  'dftjg': 'UA',
#  'pansoul': 'GR',
#  'kavyeshg': 'IN',
#  'iosouy': 'AR',
#  'steliostsip': 'GR',
#  'moh0699': 'IR',
#  'gge4567': 'UA',
#  'mrschwaggins': 'DE',
#  'probablyadamm': 'EG',
#  'kalaisaran_24': 'LK',
#  'lvkas561': 'XX',
#  'joseph8228': 'US',
#  'anoushka03': 'IN',
#  'mielmielloic': 'FR',
#  'putinxuilo12': 'UA',
#  'kikijijiaa': 'PK',
#  'mohammadchest': 'IR',
#  'vua112332': 'VN',
#  'tushar_joshi01': 'IN',
#  'crashdash': 'US',
#  'user7294050292': 'SG',
#  'shin-2003': 'KR',
#  'imjb11': 'IN',
#  'speech9': 'PL',
#  'futurekalki': 'IN',
#  'rayrayrayrayrayrrrraaaayy': 'PH',
#  'jimoosh123': 'US',
#  'asrafislam': 'BD',
#  'buttercup_aqua': 'IN',
#  'starboy-01': 'KE',
#  'prettyrosalina': 'US',
#  'bravo1xq': 'US',
#  'trip31happy': 'KR',
#  'asoto86': 'MX',
#  'eddik1981': 'RU',
#  'sebita_z': 'UY',
#  'zippo3108': 'ID',
#  'jeet_76': 'IN',
#  'arnaldurlogi': 'IS',
#  'ennnees': 'TR',
#  'abdqllah': 'IN',
#  'plazmic008': 'PK',
#  'tcathy': 'US',
#  'washinotsubasa': 'DE',
#  'harsh18raj': 'IN',
#  'keshav2362': 'IN',
#  'robuster99': 'XX',
#  'matttfranc': 'CA',
#  'aintern': 'JP',
#  'thomasshin84': 'US',
#  'raidul_x_69': 'BD',
#  'barray87': 'FR',
#  'saudtain': 'SA',
#  'harshadingavale4343343456': 'IN',
#  'thec0demaster': 'US',
#  'ed_chess11': 'KP',
#  'kingyeyo12': 'MX',
#  'radhika_0716': 'IN',
#  'rusyth': 'TH',
#  'srna_6': 'SA',
#  'emir95s': 'TR',
#  'digjoyboboy': 'BR',
#  'tattinscottadams': 'US',
#  'calcatoghju': 'FR',
#  'neilal85': 'IE',
#  'mangotour': 'KR',
#  'giornogiovanna2006': 'AZ',
#  'juansalgado04': 'US',
#  'samuel_armani': 'BG',
#  'abdullah-31-z-31': 'TR',
#  'lollipoprock': 'FR',
#  'mahdiafrasiabi': 'IR',
#  'papasrcas1936': 'BR',
#  'deliaaaa23': 'ES',
#  'pedroli88': 'PT',
#  'msalley': 'SD',
#  'adhithya_8': 'IN',
#  'hpsoepadmo': 'XX',
#  'benyami89': 'IR',
#  'kaikokun': 'ES',
#  'sukant324': 'IN',
#  'lazyybish': 'VI',
#  'megantron23': 'US',
#  'pikadasgallaxia': 'BR',
#  'maskim18': 'US',
#  'blacksheep223': 'IN',
#  'mohamedaljali': 'SD',
#  'simoon12': 'AU',
#  'vpknight': 'CA',
#  'jmr000': 'AG',
#  'nicklasholm123': 'DK',
#  'funnysly': 'FR',
#  'mani_shan': 'IN',
#  'toverbakel': 'NL',
#  'emikosaw': 'MM',
#  'mastwerr': 'BR',
#  'samichaurasiya': 'NP',
#  'japogabe': 'AR',
#  'gouranga565': 'BD',
#  'aliyak19': 'DZ',
#  'ercolorado': 'AR',
#  'i-zoro': 'IQ',
#  'd_u_k_e_01': 'PT',
#  'youbakh': 'FR',
#  'bdori8': 'HU',
#  'adderall-dependent-player': 'VI',
#  'c01092009': 'VN',
#  'chandan_86': 'IN',
#  'gianni3333334': 'IT',
#  'sonzvek': 'FR',
#  'mouadabaaqil': 'MA',
#  'newplayer169': 'HK',
#  'nofearxdd': 'LV',
#  'vedant_2777': 'IN',
#  'shahikant043': 'IN',
#  'varunmuppidi': 'IN',
#  'aizen_7007': 'IN',
#  'whohavethisname': 'FI',
#  'cipry79': 'RO',
#  'mcnasty805': 'US',
#  'apalodima': 'GR',
#  'rafailmamedow': 'RU',
#  'dassi55': 'FJ',
#  'lllll555': 'PH',
#  'tham_07': 'MY',
#  'mohammedmetwally92': 'EG',
#  'cannonaniim': 'TR',
#  'misspiperade64': 'FR',
#  'theguyyoullneverknow': 'IN',
#  'fabiana_giuli': 'IT',
#  'jehdjjse': 'RU',
#  'nitinsarod': 'IN',
#  'carax006': 'DE',
#  'nicolabaie': 'FR',
#  'ilbimbo4896830': 'IT',
#  'oakwid': 'BR',
#  'vinodkumarg': 'IN',
#  'neozeratod': 'UA',
#  'saddyboi248': 'VN',
#  'tsullysr': 'US',
#  'sharpsh00te': 'CA',
#  'gudsvc': 'BR',
#  'aries645': 'AR',
#  'nekrion': 'PL',
#  'paco_913': 'MX',
#  'weltonmattos010': 'BR',
#  'blayr9053': 'US',
#  'crisarvie': 'PH',
#  'criboch': 'IT',
#  'insizachamp': 'XX',
#  'freezear': 'US',
#  'mainconfucio': 'IT',
#  'dhanyavenkat': 'US',
#  'suvodip007': 'IN',
#  'vicentvallsmarti': 'ES',
#  'psu73': 'US',
#  'jdw1231': 'US',
#  'skinnymillonario': 'EC',
#  'chesschrisking': 'DE',
#  'jssk363': 'US',
#  'luckylama88939': 'US',
#  'jpmp1': 'CA',
#  'sai8812': 'US',
#  'demonsteiner': 'TN',
#  'faheemshoukat': 'PK',
#  'sahil78rebal': 'IN',
#  'ahmad_d70': 'SD',
#  'hiro202303': 'BE',
#  'rangerrn': 'US',
#  'checkspearito': 'MX',
#  'pbaregan': 'XE',
#  'cat_shaped_dog': 'US',
#  'chawitz2': 'TH',
#  'yousef-abbat': 'SA',
#  'amit1690': 'IN',
#  'ada9015': 'IN',
#  '06rdjl': 'DE',
#  'maya_3237': 'IN',
#  'mbatista911': 'US',
#  'titaamar': 'ES',
#  'jalinrabei_69': 'BR',
#  'regis275': 'BR',
#  'landvogt1': 'DE',
#  'santhosh442': 'IN',
#  'advikmysore': 'US',
#  'yassinooo213': 'DZ',
#  'aderlineman': 'XX',
#  'epik_gamer69420': 'PH',
#  'gokulhanda': 'IN',
#  'hoolster': 'AU',
#  'antoniomenendez': 'ES',
#  'rva_26_21_01': 'IN',
#  'piotrkarnia': 'PL',
#  'chesskh41': 'US',
#  'lizzzard704': 'CA',
#  'gasssx69': 'ID',
#  'eliascoc': 'AR',
#  'artdekker': 'BE',
#  'ruimca': 'PT',
#  'omar1007pok': 'CL',
#  'handsoffmybishop': 'CA',
#  'micmaher': 'EG',
#  'biragazyapar': 'TR',
#  'vrilgeeker': 'RU',
#  'gibbo737': 'AU',
#  'elzer000': 'PH',
#  'unknowmaster1234': 'IN',
#  'ibrahim11511': 'IN',
#  'meysame77': 'IR',
#  'murtajizmaqsood': 'PK',
#  'spudensky': 'ZA',
#  'elcin_mursalov': 'AZ',
#  'lakejumb': 'GB',
#  'irionjlt': 'US',
#  'btbremner': 'GB',
#  'thomas021958': 'DE',
#  's28091111111': 'IN',
#  'bcook0322': 'US',
#  'akenny2654': 'GB',
#  'marekmarkus': 'PL',
#  'sanryovictor': 'BR',
#  'figa338': 'PL',
#  'deepanshus42': 'IN',
#  'dimistik': 'IR',
#  'nitishkg_26': 'IN',
#  'rkvcsnrbrt': 'HU',
#  'hephaestus265': 'IN',
#  'oliverkinggabriel123': 'PH',
#  'sahal_hassan': 'IN',
#  'ayaanpdinesh': 'IN',
#  'nisant11': 'IN',
#  'nithin_mu': 'IN',
#  'dentech': 'US',
#  'yashhhhhhh95': 'US',
#  'solhah': 'ID',
#  'phantomy001': 'IN',
#  'karaly7171': 'HU',
#  'deathcorps': 'AU',
#  'azsssbarboza': 'ID',
#  'npgaming2971': 'VN',
#  'itseenz': 'US',
#  'snowy_bee': 'BG',
#  'etoyari': 'ES',
#  'new_pengu1n': 'SA',
#  'bukajek12': 'PL',
#  'mesi122': 'VN',
#  'plinochallenged': 'US',
#  'yeayeayeaeya': 'NZ',
#  'mustardmaker84': 'US',
#  'washimjrnrt': 'BD',
#  'bwill1177': 'US',
#  'werner_68': 'IL',
#  'logfriel': 'GB',
#  'bhaveshraut_79': 'IN',
#  'parthpasrija': 'IN',
#  'minaboloko': 'ES',
#  'bychechen': 'TR',
#  'bhishma-chanda': 'IN',
#  'fatur11011': 'ID',
#  'phonk_dem': 'PH',
#  'jesus712': 'US',
#  'fitzgerald_24': 'IN',
#  'cj0326': 'PH',
#  'fakiris123': 'GR',
#  'phyo159335': 'MM',
#  'magnu-mi': 'NO',
#  'talk2krvs': 'US',
#  'teba989': 'IQ',
#  'mohcine10': 'FR',
#  'lakshan3970': 'IN',
#  'mauriberna': 'IT',
#  'zawwintun7': 'GB',
#  'ishantx2007': 'IN',
#  'tonkokg': 'NL',
#  'dssirecho': 'ZA',
#  'bibhukishandas': 'IN',
#  'datthu7': 'IN',
#  'shawayush9876': 'IN',
#  'transformr03l0x': 'PH',
#  'carlcd1032': 'CA',
#  'ffudyojgio': 'KH',
#  'body836': 'DE',
#  'ahriman1979': 'GB',
#  'mixolydio': 'CL',
#  'ayyextn': 'AU',
#  'talasuli': 'US',
#  'r1nir9': 'RU',
#  'ahmett_aldmr': 'TR',
#  'mu3clec0w1323': 'KR',
#  'bezz100': 'AU',
#  'franflumo': 'NL',
#  'jonc86': 'BR',
#  'lipims': 'FR',
#  'kalleeko': 'US',
#  'sysko31': 'FR',
#  'ismael2508': 'MX',
#  '10prr': 'JP',
#  'ersalinas18': 'US',
#  'kunal1849': 'IN',
#  'riteshpandu': 'IN',
#  'shivrajmalap': 'IN',
#  'jgfcjhfcjhtfjht': 'AU',
#  'dfgjffhj': 'RU',
#  'aldigaler': 'ID',
#  'ragas090': 'NP',
#  'praveen-pachar': 'IN',
#  'meenalmaroo': 'IN',
#  'favoriteattic': 'RU',
#  'shadown789': 'BE',
#  'sandisuhada': 'ID',
#  'samdenovo': 'BR',
#  'so_bad666': 'MM',
#  'wengkail1234': 'MY',
#  'zinrick': 'FR',
#  'strykerdav9': 'US',
#  'sweetcheeks1717': 'ES',
#  'lhzpx': 'CO',
#  'tatatiii': 'JP',
#  'jerivy10': 'AU',
#  'gabba-gabba-hey': 'AR',
#  'chamuyeithor': 'CL',
#  'jefjan92': 'SE',
#  'sulabeu': 'BD',
#  'marcos19782016': 'BR',
#  'luizfilho0': 'BR',
#  'keo-shan': 'FR',
#  'ibigshane123': 'GB',
#  'norbers': 'IT',
#  'vktinho': 'BR',
#  'retrox_ea': 'AR',
#  'altamash1611': 'IN',
#  'pierre-mcr': 'FR',
#  'abhibadal': 'IN',
#  'bunnydinh': 'IN',
#  'gab-xi': 'IT',
#  'dorkybug': 'IN',
#  'erle1950': 'DE',
#  'mrfsolefield': 'GB',
#  'masterjam1203': 'MX',
#  'bywen': 'ES',
#  'ashish14536': 'IN',
#  'anorjay': 'NG',
#  'mount_average': 'XX',
#  'ponteuspilate': 'RS',
#  'olegvnm': 'CZ',
#  'iiiepilok': 'RU',
#  'samyak_7': 'NP',
#  'dianaodb': 'IT',
#  'omeganer1912': 'IL',
#  'donjohnmaza': 'US',
#  'alermooo': 'UA',
#  'natmoua': 'US',
#  'subin1023': 'IN',
#  'matanya457': 'IL',
#  'lucasguilhermexx': 'BR',
#  'dingle_bees': 'US',
#  'quiquedrin': 'ES',
#  'blaqkinkade': 'NG',
#  'cyclistmass': 'US',
#  'andreitanasov': 'MD',
#  'xavierrenk': 'US',
#  'bylek3': 'PL',
#  'roro1918': 'IN',
#  'franstruffolino': 'AR',
#  'playerzxx': 'TR',
#  'msviroy': 'IN',
#  'gigi3la': 'GE',
#  'mikabety2012': 'BR',
#  'bobkobeissi': 'LB',
#  'ankush9897': 'IN',
#  'alban1214': 'XK',
#  'mircoalessandrini': 'IT',
#  'abdullayef017': 'AZ',
#  'edu55554': 'BR',
#  'bandex256': 'UG',
#  'tamermansi': 'EG',
#  'serginhociclone': 'BR',
#  'stamphybroff': 'GB',
#  'rijul0404': 'IN',
#  'peter_nabil': 'EG',
#  'luckymugen': 'IT',
#  'grid_12': 'UA',
#  'amibm': 'GB',
#  'simon_zehn': 'DE',
#  'kazuhanezuko': 'VN',
#  'lebosky': 'XC',
#  'supto2023': 'BD',
#  'rafafm98': 'BR',
#  'emailterribile': 'IT',
#  'samyscoob': 'FR',
#  'szemil_gg': 'PL',
#  'a7madtayyem': 'PS',
#  'fimanave': 'IL',
#  'salvatore_gianfagna': 'IT',
#  'jonasmevel': 'FR',
#  'pablo-j-dc': 'ES',
#  'md73008': 'US',
#  'amoregarden': 'NG',
#  'sibuabraham': 'IN',
#  'loudwhisper123': 'NG',
#  'harsh_all': 'ZA',
#  'mrevivo': 'IL',
#  'aminec44': 'FR',
#  'fakepopsmoke': 'FR',
#  'pablo_fx': 'ES',
#  'berlinmax': 'DE',
#  'adinath007': 'IN',
#  'bfnikai': 'PH',
#  'paveltopg': 'RU',
#  'lkylny379': 'EG',
#  'jibbidy7': 'US',
#  'silviaari': 'BG',
#  'marry2596': 'PK',
#  'multiqalbiadi': 'ID',
#  'russell_uy': 'PH',
#  'shantokhan74': 'BD',
#  'ali-valbuena': 'VE',
#  'bunclebarrancs': 'ES',
#  'fazarxd': 'ID',
#  'aaliyaarora': 'DE',
#  'witesik': 'PL',
#  'afifafifafif': 'MY',
#  'twilighthaha': 'PH',
#  'ranaraman': 'IN',
#  'i_sum': 'KR',
#  'lesleymambwe': 'ZM',
#  'skonfort': 'TN',
#  'granifol': 'US',
#  'seven960': 'MX',
#  'parevechulent': 'US',
#  'albiladi': 'SA',
#  'minkaungst': 'MM',
#  'hertizord': 'GB',
#  'mohamedeid1234884847': 'EG',
#  'herobot01': 'KR',
#  'mityadegurchaff': 'RU',
#  'r0or0o': 'FI',
#  'laxman1956': 'IN',
#  'gauravarora2001': 'IN',
#  'seti71': 'GB',
#  'studermarc': 'CH',
#  'pepe4000sgf': 'MX',
#  'sergiossssss': 'UA',
#  'solalteng': 'US',
#  'xaviphone': 'FR',
#  'sigaso': 'AR',
#  'jwadinho5': 'IQ',
#  'churchmom': 'US',
#  'marianlev': 'UA',
#  'checkmate_211': 'IN',
#  'hussien_farouk': 'EG',
#  'jackbikar': 'BE',
#  'antoine_p57': 'FR',
#  'abelbock': 'IT',
#  'bazingggaaaa': 'IN',
#  'deplayted': 'RU',
#  'jakov837': 'IL',
#  'fran4ways': 'ZA',
#  'pctyk': 'XX',
#  'momo19811': 'GB',
#  'olushol': 'NG',
#  'mayck2811': 'BR',
#  'th3pers0n': 'US',
#  'maverack': 'GH',
#  'kadarkaraiselvam': 'IN',
#  'oleg500qm': 'SC',
#  'duxducisduce': 'IT',
#  'fabiocacarioca': 'IT',
#  'extra_thicc1029': 'AU',
#  'jeabkaewlod2010': 'NL',
#  'stvndouthim': 'US',
#  'aditrap': 'VA',
#  'ekouti': 'SG',
#  'kung4ukimaz': 'US',
#  'rizzz13': 'ID',
#  'kanishkamohapatra': 'IN',
#  'vivek_02': 'EU',
#  'tuzzinduk13': 'BR',
#  'flopchess1111': 'AU',
#  'diceychesd': 'NG',
#  'unbreakable1020': 'IN',
#  'lebzin10': 'ZA',
#  'kabuthitam': 'ID',
#  'gospodintodorov42': 'BG',
#  'natalia2205': 'PL',
#  'tomaustin1': 'FR',
#  'ferbigga132': 'PK',
#  'chesstyme1': 'US',
#  'maximuswagimus': 'JP',
#  'amir_haji': 'IR',
#  'luka_skywalker7': 'FI',
#  'zaza2013572': 'US',
#  'vroasatryan1221': 'AM',
#  'kurtlegrand': 'NL',
#  'rdbrnco': 'PT',
#  'nsc_roberto': 'BR',
#  'atsantos17': 'BR',
#  'nachimixtou': 'CL',
#  'pranav21127': 'IN',
#  'ben_lakra': 'IN',
#  'alavellana': 'US',
#  'hoodedowl': 'NL',
#  'dornocu': 'BR',
#  'robo-knight': 'US',
#  'kp_physics': 'IN',
#  'adrza': 'VE',
#  'jakob-g': 'DE',
#  'huligun2009': 'KR',
#  'brenflan': 'IE',
#  'abhi9948': 'IN',
#  'quicksilverz95': 'US',
#  'atha2456': 'IN',
#  'yashbaghel1729': 'IN',
#  'bibek3108': 'IN',
#  'chrisdaniel2015': 'AU',
#  'wonderia123': 'BD',
#  'ig_deveshwar8979': 'IN',
#  'ajmioussamafg': 'TN',
#  'fcberlin': 'AR',
#  'arsul1': 'NO',
#  'king_faizan786': 'GB',
#  'ryuki_94': 'JP',
#  'dumm_human': 'IN',
#  'azrah45': 'CA',
#  'federob3': 'IT',
#  'shadow-karim': 'DZ',
#  'yukansenshi': 'IN',
#  'pkh0404': 'IN',
#  'yashy09': 'IN',
#  'noctisspassky': 'ID',
#  'jamoes21': 'DE',
#  'obbyob': 'SV',
#  'lulunba1': 'CA',
#  'noriakiakakyoinlerolero': 'IN',
#  'raedrafikwasfy': 'EG',
#  'f4k4pp4': 'PL',
#  'darshan-kakanur': 'IN',
#  'liam_addo': 'GB',
#  'jeandruk': 'FR',
#  'pattycake91': 'GB',
#  'ledapperduck': 'US',
#  'shfdfhji': 'FR',
#  'nuttywun': 'NZ',
#  'x-0971292412': 'XX',
#  'gh_ost22': 'GB',
#  'mokaddm': 'US',
#  'rob_khaos': 'US',
#  'dagoneber': 'DE',
#  'floechec92': 'FR',
#  'kerolosashraf1': 'EG',
#  'mrhall1923': 'US',
#  'zendobenzo': 'ES',
#  'satis2': 'CY',
#  'ppw25': 'CZ',
#  'robertopinguim': 'BR',
#  'jorgecarlsen1': 'CL',
#  'k4sirg4': 'TR',
#  'asnejuve': 'NO',
#  'oliveryujiro_123': 'TR',
#  'jabinelin': 'DO',
#  'andrelbmoog': 'BR',
#  'webbeast3': 'EG',
#  'aaronmo13': 'US',
#  'marcithebishop': 'HU',
#  'masterbaiter_12': 'KZ',
#  'nigzouz': 'CA',
#  'v_4o': 'IQ',
#  'eason8': 'AU',
#  'rayantr': 'LB',
#  'emilozio90': 'IT',
#  'skynet0_0': 'FR',
#  'deaglemoon': 'IT',
#  'calinbaros': 'RO',
#  'chesseteer1': 'NG',
#  'goldbybe': 'GB',
#  'arnavkarekar69': 'IN',
#  'wainadoiwonderman': 'FJ',
#  'benjaminvmarques': 'BR',
#  'spoonfeed': 'GB',
#  'sanjay97297': 'IN',
#  'pedoslayerr': 'JO',
#  'rishii_183': 'IN',
#  'lluisjduran': 'XC',
#  'dumbman_101': 'IN',
#  'zangygalaqtioni': 'GE',
#  'alexisknk': 'FR',
#  'nathan1234452': 'GB',
#  'spaslba': 'IT',
#  'mughalspy': 'IN',
#  'yusefarghand': 'IR',
#  'mclenovo': 'AU',
#  'arkabanerjee381': 'IN',
#  'unprofesionally': 'VN',
#  'abhi_shekkkk': 'IN',
#  'qaidana': 'KZ',
#  'chbb0': 'BR',
#  'asfy6': 'IL',
#  'cbfa17': 'AF',
#  'stewiefm': 'ES',
#  'its_ab_555': 'IN',
#  'muhannad30': 'SA',
#  'jijiholoo': 'AU',
#  'oarabilefidel': 'ZA',
#  'mumiaabu': 'US',
#  'arcangelo54': 'IT',
#  'rmz704t': 'IT',
#  'florin_id': 'RO',
#  'stubb173': 'NO',
#  'mystic-mo': 'DE',
#  'kontolodonberanakmega': 'ID',
#  'paolosassi': 'IT',
#  's3odplayz': 'SA',
#  'pattyrick808': 'US',
#  'ken051807': 'PH',
#  'unveilcloth': 'PH',
#  'unknownmercthethird': 'ZA',
#  'wearytwo': 'US',
#  'leonardopratess': 'BR',
#  'sethalethicus': 'US',
#  'timmymac42': 'US',
#  'takehirotomiyasu': 'JP',
#  'braca911': 'MX',
#  'hpc2sweet': 'US',
#  'lord-ao': 'BT',
#  'tacj47': 'US',
#  'ryouasukan': 'VN',
#  'skinnydog1973': 'XE',
#  'fahadarekar': 'IN',
#  'kakotov': 'CL',
#  'nafihmuhammed4': 'IN',
#  'opidet': 'DE',
#  'kingadam231108': 'EG',
#  'lowskillme': 'RU',
#  'elhassen03': 'TN',
#  'finsbury_park': 'GB',
#  'sonerpetek17': 'TR',
#  'jeanaymart': 'FR',
#  'bigsockss': 'US',
#  'yeid947483': 'PE',
#  'lonely_chopstick': 'JP',
#  'aiglesiasm': 'ES',
#  'killerkingyt': 'IR',
#  'elvetius': 'IT',
#  'erik7283': 'MX',
#  'sergeychess23': 'UA',
#  'chessscrofa': 'XX',
#  'jo0kii': 'EG',
#  'ddxirvx': 'MX',
#  'colorfularmy': 'US',
#  'gm-samyak-08': 'IN',
#  'cuikanne': 'GB',
#  'gondon_1': 'UA',
#  'devam303': 'IN',
#  'nazmazed': 'US',
#  'bepirocia': 'IT',
#  'dieg84': 'FR',
#  'jxyuun': 'DE',
#  'dravyajha': 'IN',
#  'a_kid_named_alexander': 'PH',
#  'potatosunglasses': 'BD',
#  'rockrax': 'FR',
#  'uctien': 'VN',
#  'jordanaluis': 'ES',
#  'zaherarraf': 'IL',
#  'yousef3011': 'EG',
#  'jerryjo91': 'EG',
#  'monkeymyster': 'GB',
#  'gmalfomay2': 'ES',
#  'markptc': 'US',
#  'belanov03': 'FR',
#  'sikooooooooooooooo': 'EG',
#  'jubbeee': 'AU',
#  'tharwat13': 'EG',
#  'wwendyyj': 'CH',
#  'yamir49': 'CL',
#  'yassine_mj9': 'MA',
#  '8point4': 'FR',
#  'md17175': 'IN',
#  'pinkcypher': 'GB',
#  'kramar-urii': 'RU',
#  'capizaguirre': 'MX',
#  'willywonkahd': 'US',
#  'geyzuski1111': 'IN',
#  'x-7404271567': 'XX',
#  'nachtvampir': 'DE',
#  'eiderlof': 'FR',
#  'hiram721': 'MX',
#  'kenyi2807': 'PE',
#  ...}

# %%
gold_df['opponent_country'] = gold_df['opponent'].map(opponent_country_map)
gold_df[gold_df['opponent_country'].isna()]
# Out:
# Empty DataFrame
# Columns: [uuid, player, player_elo, opponent, opponent_elo, player_color, opponent_color, result, time_class, time_control, opening, rated, end_datetime, player_accuracy, opponent_accuracy, url, opponent_country]
# Index: []

# %%
output_path = f"chess_games_{username}_gold.csv"

gold_df.to_csv(
    output_path,
    index=False,
    encoding="utf-8"
)

# %%
archives[-1]
# Out:
# 'https://api.chess.com/pub/player/ahmedbdk/games/2025/09'
